# %% [markdown]
# # Maze CNN Classifier
#
# **Silent Cartographer — COSC 4368 AI Spring 2026**
#
# | #   | Label       | Description           |
# | --- | ----------- | --------------------- |
# | 0   | `path`      | Open traversable cell |
# | 1   | `wall`      | Blocked cell          |
# | 2   | `death_pit` | Fire emoji            |
# | 3   | `confusion` | Yellow smiley pads    |
# | 4   | `tp_orange` | Orange teleport pad   |
# | 5   | `tp_green`  | Green teleport pad    |
# | 6   | `tp_purple` | Purple teleport pad   |
# | 7   | `tp_red`    | Red teleport pad      |
# | 8   | `start`     | Start cell            |
# | 9   | `goal`      | Goal cell             |
#
# **Workflow:** Extract → Label → Dataset → Train → Evaluate → Test with agent

# %% [markdown]
# ## 0. Imports & Constants

# %%
import os, glob, shutil
import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import ipywidgets as widgets
from IPython.display import display, clear_output
from PIL import Image
from maze import MazeLoader

CELL_SIZE  = 16
WALL_THICK = 2
INNER_SIZE = CELL_SIZE - 2 * WALL_THICK   # 12
MODEL_PATH = "maze_cnn.pt"
SEED_DIR   = "unique_hazards"
LABEL_DIR  = "labeled_hazards"
MAZE_FILES = ["MAZE_1.png", "MAZE_2.png"]

CLASS_NAMES = [
    "path", "wall", "death_pit", "confusion",
    "tp_orange", "tp_green", "tp_purple", "tp_red",
    "start", "goal"
]
NUM_CLASSES = len(CLASS_NAMES)

LABEL_PATH   = 0
LABEL_WALL   = 1
LABEL_FIRE   = 2
LABEL_CONF   = 3
LABEL_TPO    = 4
LABEL_TPG    = 5
LABEL_TPP    = 6
LABEL_TPR    = 7
LABEL_START  = 8
LABEL_GOAL   = 9

CLASS_COLOURS = [
    (220,220,220),  # path
    ( 30, 30, 30),  # wall
    (255, 60, 60),  # death_pit
    (255,230,  0),  # confusion
    (255,140,  0),  # tp_orange
    ( 40,200, 80),  # tp_green
    (160, 50,255),  # tp_purple
    (200,  0,  0),  # tp_red
    (  0,230,100),  # start
    (  0,210,255),  # goal
]

print(f"PyTorch {torch.__version__}  |  CUDA: {torch.cuda.is_available()}")
print(f"Classes: {CLASS_NAMES}")
# Out:
# PyTorch 2.11.0+cpu  |  CUDA: False
# Classes: ['path', 'wall', 'death_pit', 'confusion', 'tp_orange', 'tp_green', 'tp_purple', 'tp_red', 'start', 'goal']

# %% [markdown]
# ## 1. NCC Helper

# %%
def ncc(a: np.ndarray, b: np.ndarray) -> float:
    a = a.astype(np.float32) - a.mean()
    b = b.astype(np.float32) - b.mean()
    d = np.linalg.norm(a) * np.linalg.norm(b)
    return float(np.sum(a * b) / d) if d > 1e-8 else 0.0


def has_warm_color(bgr):
    """True if patch has warm saturated pixels — likely a hazard, never a plain wall."""
    hsv = cv2.cvtColor(bgr, cv2.COLOR_BGR2HSV)
    fg  = (hsv[:,:,1] > 60) & (hsv[:,:,2] > 80)
    return int(fg.sum()) >= 8

# %% [markdown]
# ## 2. Extract Raw Patches → `unique_hazards/`
#
# Extracts all non-white hazard-looking patches from every maze. `force=True` always re-runs.

# %%
def extract_raw_patches(maze_files, out_dir=SEED_DIR, dedup_thresh=0.92, force=False):
    existing = glob.glob(f"{out_dir}/*.png")
    if existing and not force:
        print(f"'{out_dir}/' has {len(existing)} images. Pass force=True to re-extract.")
        return

    os.makedirs(out_dir, exist_ok=True)
    saved_patches, total = [], 0

    for maze_path in maze_files:
        if not os.path.exists(maze_path):
            print(f"  {maze_path} not found, skipping"); continue

        loader = MazeLoader(maze_path)
        h, w   = loader.maze_height_cells, loader.maze_width_cells
        name   = os.path.splitext(os.path.basename(maze_path))[0]
        count  = 0

        for r in range(h):
            for c in range(w):
                y0  = r * CELL_SIZE + WALL_THICK
                x0  = c * CELL_SIZE + WALL_THICK
                bgr = loader.bgr[y0:y0+INNER_SIZE, x0:x0+INNER_SIZE]

                # Skip near-white (path/wall)
                hsv = cv2.cvtColor(bgr, cv2.COLOR_BGR2HSV)
                fg  = ~((hsv[:,:,1] < 30) & (hsv[:,:,2] > 200))
                if int(fg.sum()) < 10:
                    continue

                p = cv2.resize(bgr, (INNER_SIZE, INNER_SIZE), interpolation=cv2.INTER_NEAREST)
                if any(ncc(p, ex) >= dedup_thresh for ex in saved_patches):
                    continue

                fname = f"{name}_r{r:02d}_c{c:02d}.png"
                cv2.imwrite(os.path.join(out_dir, fname), p)
                saved_patches.append(p)
                count += 1

        print(f"  {maze_path}: {count} unique patches")
        total += count

    print(f"Total: {total} patches saved to '{out_dir}/'")


extract_raw_patches(MAZE_FILES, force=True)
# Out:
#   MAZE_1.png: 26 unique patches
#   MAZE_2.png: 6 unique patches
# Total: 32 patches saved to 'unique_hazards/'

# %% [markdown]
# ## 3. Manual Labeling Tool
#
# Each patch is shown at 8× zoom. Click the correct label. Progress auto-saves to `labeled_hazards/`.
# Re-running resumes where you left off.

# %%
os.makedirs(LABEL_DIR, exist_ok=True)

already_labeled = set()
for p in glob.glob(f"{LABEL_DIR}/*.png"):
    parts = os.path.basename(p).split("_", 2)
    if len(parts) == 3:
        already_labeled.add(parts[2])

all_images   = [p for p in sorted(glob.glob(f"{SEED_DIR}/*.png"))
                if os.path.basename(p) not in already_labeled]
idx_state    = {"i": 0}
label_counts = {l: len(glob.glob(f"{LABEL_DIR}/{l}_*.png")) for l in CLASS_NAMES}
print(f"{len(all_images)} images to label  |  {len(already_labeled)} already done")


def save_labeled(fpath, label):
    n     = label_counts[label]
    fname = f"{label}_{n:03d}_{os.path.basename(fpath)}"
    shutil.copy(fpath, os.path.join(LABEL_DIR, fname))
    label_counts[label] += 1


img_widget   = widgets.Image(format="png", width=160, height=160)
progress_bar = widgets.IntProgress(value=0, min=0, max=max(len(all_images), 1),
                                   description="Progress:",
                                   layout=widgets.Layout(width="420px"))
status_lbl = widgets.Label(value="")
info_lbl   = widgets.Label(value="")


def show_current():
    i = idx_state["i"]
    progress_bar.value = i
    if i >= len(all_images):
        img_widget.value = b""
        info_lbl.value   = ""
        status_lbl.value = f"✓ All {i} images labeled!"
        return
    fpath = all_images[i]
    bgr   = cv2.imread(fpath, cv2.IMREAD_COLOR)
    big   = cv2.resize(bgr, (INNER_SIZE*8, INNER_SIZE*8), interpolation=cv2.INTER_NEAREST)
    _, buf = cv2.imencode(".png", big)
    img_widget.value = buf.tobytes()
    info_lbl.value   = f"{i+1}/{len(all_images)}  —  {os.path.basename(fpath)}"


def make_btn(label, colour):
    b = widgets.Button(description=label,
                       style={"button_color": colour},
                       layout=widgets.Layout(width="110px", height="36px"))
    def on_click(_):
        if idx_state["i"] < len(all_images):
            save_labeled(all_images[idx_state["i"]], label)
            status_lbl.value = f"✓  saved as '{label}'"
        idx_state["i"] += 1
        show_current()
    b.on_click(on_click)
    return b


btn_skip = widgets.Button(description="Skip",
                          style={"button_color": "#aaaaaa"},
                          layout=widgets.Layout(width="80px", height="36px"))
btn_back = widgets.Button(description="← Back",
                          layout=widgets.Layout(width="80px", height="36px"))

def on_skip(_): idx_state["i"] += 1; status_lbl.value = "— skipped"; show_current()
def on_back(_):
    if idx_state["i"] > 0: idx_state["i"] -= 1
    show_current()

btn_skip.on_click(on_skip)
btn_back.on_click(on_back)

row_hazard = widgets.HBox([
    make_btn("death_pit", "#ff6b6b"),
    make_btn("confusion", "#ffd93d"),
    make_btn("tp_orange", "#ffb347"),
    make_btn("tp_green",  "#6bcb77"),
    make_btn("tp_purple", "#c77dff"),
    make_btn("tp_red",    "#cc0000"),
])
row_other = widgets.HBox([
    make_btn("path",  "#dddddd"),
    make_btn("wall",  "#888888"),
    make_btn("start", "#00e676"),
    make_btn("goal",  "#00e5ff"),
    btn_skip, btn_back,
])

display(widgets.VBox([
    progress_bar, info_lbl, img_widget, status_lbl,
    widgets.Label("── Hazards ──────────────────────────────────────"),
    row_hazard,
    widgets.Label("── Other ─────────────────────────────────────────"),
    row_other,
]))
show_current()
# Out:
# 31 images to label  |  39 already done
# VBox(children=(IntProgress(value=0, description='Progress:', layout=Layout(width='420px'), max=31), Label(valu…

# %% [markdown]
# ## 4. Review Labeled Seeds

# %%
fig, axes = plt.subplots(2, NUM_CLASSES, figsize=(NUM_CLASSES * 1.7, 4))
fig.suptitle("Labeled seeds — up to 2 examples per class", fontsize=11)

for ci, name in enumerate(CLASS_NAMES):
    paths = sorted(glob.glob(f"{LABEL_DIR}/{name}_*.png"))
    for row in range(2):
        ax = axes[row, ci]
        if row < len(paths):
            img = cv2.cvtColor(cv2.imread(paths[row]), cv2.COLOR_BGR2RGB)
            ax.imshow(cv2.resize(img, (48,48), interpolation=cv2.INTER_NEAREST))
        else:
            ax.imshow(np.ones((48,48,3)))
        ax.axis("off")
        if row == 0:
            ax.set_title(f"{name}\n({len(paths)})", fontsize=7)

plt.tight_layout(); plt.show()

# %% [markdown]
# ## 5. Build Dataset via NCC + Boundary-Pixel Wall Detection

# %%
HAZARD_LABELS = ["death_pit", "confusion", "tp_orange", "tp_green",
                 "tp_purple", "tp_red"]
NCC_THRESHOLD = 0.45   # lower threshold catches more fire cells


def load_seeds(label_dir=LABEL_DIR):
    seeds = {}
    for name in CLASS_NAMES:
        paths  = sorted(glob.glob(f"{label_dir}/{name}_*.png"))
        loaded = [cv2.resize(cv2.imread(p, cv2.IMREAD_COLOR),
                             (INNER_SIZE, INNER_SIZE), interpolation=cv2.INTER_NEAREST)
                  for p in paths if cv2.imread(p) is not None]
        if loaded:
            seeds[name] = loaded
            print(f"  {name:<12}: {len(loaded)} seed(s)")
    return seeds


def is_path_cell(loader, r, c):
    """Check boundary pixels — matches environment.py adjacency logic."""
    ma    = loader.maze_array
    hm, wm = ma.shape[0]-1, ma.shape[1]-1
    hc, wc = loader.maze_height_cells, loader.maze_width_cells
    mid   = CELL_SIZE // 2
    checks = []
    if r+1 < hc: checks.append((min((r+1)*CELL_SIZE, hm), min(c*CELL_SIZE+mid, wm)))
    if r   > 0:  checks.append((min(r*CELL_SIZE,     hm), min(c*CELL_SIZE+mid, wm)))
    if c+1 < wc: checks.append((min(r*CELL_SIZE+mid, hm), min((c+1)*CELL_SIZE, wm)))
    if c   > 0:  checks.append((min(r*CELL_SIZE+mid, hm), min(c*CELL_SIZE,     wm)))
    return any(bool(ma[py, px]) for py, px in checks)


def best_hazard_match(patch_bgr, seeds):
    best_label, best_score = None, -1.0
    for label in HAZARD_LABELS:
        if label not in seeds: continue
        for seed in seeds[label]:
            s = ncc(patch_bgr, seed)
            if s > best_score:
                best_score, best_label = s, label
    return (best_label if best_score >= NCC_THRESHOLD else None), best_score


def build_dataset(maze_path, seeds):
    loader = MazeLoader(maze_path)
    h, w   = loader.maze_height_cells, loader.maze_width_cells
    sc     = loader.pixel_to_cell(*loader.start_pos)
    gc     = loader.pixel_to_cell(*loader.goal_pos)

    patches, labels = [], []
    for r in range(h):
        for c in range(w):
            y0  = r * CELL_SIZE + WALL_THICK
            x0  = c * CELL_SIZE + WALL_THICK
            bgr = loader.bgr[y0:y0+INNER_SIZE, x0:x0+INNER_SIZE]
            rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
            t   = np.transpose(rgb, (2, 0, 1))

            pos = (r, c)
            if pos == sc:
                label = LABEL_START
            elif pos == gc:
                label = LABEL_GOAL
            else:
                hazard, _ = best_hazard_match(bgr, seeds)
                if hazard is not None:
                    label = CLASS_NAMES.index(hazard)
                elif has_warm_color(bgr):
                    # Coloured but unmatched — safer to call path than wall
                    label = LABEL_PATH
                else:
                    label = LABEL_PATH if is_path_cell(loader, r, c) else LABEL_WALL

            patches.append(t)
            labels.append(label)

    return np.stack(patches).astype(np.float32), np.array(labels, dtype=np.int64)


print("Loading labeled seeds...")
seeds = load_seeds(LABEL_DIR)

if not seeds:
    print("\n⚠ No seeds found — run the labeling tool first (Cell 3).")
else:
    print("\nBuilding dataset...")
    all_patches, all_labels = [], []
    for mf in MAZE_FILES:
        if not os.path.exists(mf): continue
        print(f"  {mf}")
        p, l = build_dataset(mf, seeds)
        all_patches.append(p); all_labels.append(l)
        unique, counts = np.unique(l, return_counts=True)
        for u, cnt in zip(unique, counts):
            print(f"    {CLASS_NAMES[u]:<12}: {cnt}")

    patches = np.concatenate(all_patches)
    labels  = np.concatenate(all_labels)
    print(f"\nTotal: {len(labels)} cells")
# Out:
# Loading labeled seeds...
#   death_pit   : 18 seed(s)
#   confusion   : 6 seed(s)
#   tp_orange   : 2 seed(s)
#   tp_green    : 2 seed(s)
#   tp_purple   : 11 seed(s)
#
# Building dataset...
#   MAZE_1.png
#     path        : 4029
#     death_pit   : 54
#     confusion   : 4
#     tp_orange   : 3
#     tp_green    : 2
#     tp_purple   : 2
#     start       : 1
#     goal        : 1
#   MAZE_2.png
#     path        : 3965
#     death_pit   : 129
#     start       : 1
#     goal        : 1
#
# Total: 8192 cells

# %% [markdown]
# ## 6. Dataset Samples per Class

# %%
fig, axes = plt.subplots(3, NUM_CLASSES, figsize=(NUM_CLASSES * 1.7, 5))
fig.suptitle("Dataset samples per class", fontsize=11)

for ci, name in enumerate(CLASS_NAMES):
    mask = np.where(labels == ci)[0]
    for row in range(3):
        ax = axes[row, ci]
        if row < len(mask):
            img = np.transpose(patches[mask[row]], (1,2,0))
            ax.imshow(img, interpolation="nearest")
        else:
            ax.imshow(np.ones((INNER_SIZE,INNER_SIZE,3)))
        ax.axis("off")
        if row == 0:
            ax.set_title(f"{name}\n({len(mask)})", fontsize=7)

plt.tight_layout(); plt.show()

# %% [markdown]
# ## 7. PyTorch Dataset

# %%
class MazeCellDataset(Dataset):
    def __init__(self, patches, labels, augment=False):
        self.patches = torch.from_numpy(patches)
        self.labels  = torch.from_numpy(labels)
        self.augment = augment

    def __len__(self): return len(self.labels)

    def __getitem__(self, idx):
        x = self.patches[idx].clone()
        if self.augment:
            if torch.rand(1) > 0.5: x = torch.flip(x, dims=[2])
            if torch.rand(1) > 0.5: x = torch.flip(x, dims=[1])
            x = (x + (torch.rand(1) - 0.5) * 0.08).clamp(0, 1)
        return x, self.labels[idx]


BATCH = 128
n     = len(labels)
idx   = np.random.permutation(n)
split = int(n * 0.9)
tr_idx, va_idx = idx[:split], idx[split:]

tr_ds = MazeCellDataset(patches[tr_idx], labels[tr_idx], augment=True)
va_ds = MazeCellDataset(patches[va_idx], labels[va_idx])
tr_dl = DataLoader(tr_ds, batch_size=BATCH, shuffle=True,  num_workers=0)
va_dl = DataLoader(va_ds, batch_size=BATCH, shuffle=False, num_workers=0)
print(f"Train: {len(tr_ds)}  Val: {len(va_ds)}")
# Out:
# Train: 7372  Val: 820

# %% [markdown]
# ## 8. CNN Architecture

# %%
class MazeCellCNN(nn.Module):
    """(B,3,12,12) → (B,NUM_CLASSES). Two conv blocks + FC."""
    def __init__(self, num_classes=NUM_CLASSES):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3,  32, 3, padding=1), nn.BatchNorm2d(32), nn.ReLU(inplace=True),
            nn.Conv2d(32, 32, 3, padding=1), nn.BatchNorm2d(32), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
        )
        self.head = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64*3*3, 128), nn.ReLU(inplace=True), nn.Dropout(0.4),
            nn.Linear(128, num_classes),
        )

    def forward(self, x): return self.head(self.features(x))

    def predict(self, patch_bgr):
        rgb = cv2.cvtColor(patch_bgr, cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
        t   = torch.from_numpy(np.transpose(rgb, (2,0,1))).unsqueeze(0)
        with torch.no_grad():
            probs = F.softmax(self(t), dim=1)
            conf, cls = probs.max(dim=1)
        return int(cls.item()), float(conf.item())

    def save(self, path=MODEL_PATH):
        torch.save(self.state_dict(), path); print(f"Saved → {path}")

    @classmethod
    def load(cls, path=MODEL_PATH):
        m = cls()
        m.load_state_dict(torch.load(path, map_location="cpu"))
        m.eval(); return m


model = MazeCellCNN()
print(f"Parameters: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Parameters: 141,098

# %% [markdown]
# ## 9. Training

# %%
EPOCHS = 30
LR     = 1e-3

counts  = np.bincount(labels, minlength=NUM_CLASSES).astype(np.float32)
counts  = np.where(counts == 0, 1, counts)
weights = torch.tensor(1.0 / counts)
weights = weights / weights.sum() * NUM_CLASSES

criterion = nn.CrossEntropyLoss(weight=weights)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)
history   = {"tr_loss": [], "tr_acc": [], "va_acc": []}
best_va   = 0.0

for epoch in range(1, EPOCHS + 1):
    model.train()
    tr_loss = tr_correct = tr_total = 0
    for x, y in tr_dl:
        optimizer.zero_grad()
        out  = model(x); loss = criterion(out, y)
        loss.backward(); optimizer.step()
        tr_loss    += loss.item() * len(y)
        tr_correct += (out.argmax(1) == y).sum().item()
        tr_total   += len(y)
    scheduler.step()

    model.eval()
    va_correct = va_total = 0
    with torch.no_grad():
        for x, y in va_dl:
            out = model(x)
            va_correct += (out.argmax(1) == y).sum().item()
            va_total   += len(y)

    tr_acc = tr_correct / tr_total * 100
    va_acc = va_correct / va_total * 100
    history["tr_loss"].append(tr_loss / tr_total)
    history["tr_acc"].append(tr_acc)
    history["va_acc"].append(va_acc)

    tag = ""
    if va_acc > best_va:
        best_va = va_acc; model.save(MODEL_PATH); tag = " ★"

    print(f"Epoch {epoch:3d}/{EPOCHS}  loss={tr_loss/tr_total:.4f}  "
          f"train={tr_acc:.1f}%  val={va_acc:.1f}%{tag}")

print(f"\nBest val accuracy: {best_va:.2f}%")
# Out:
# Saved → maze_cnn.pt
# Epoch   1/30  loss=1.1823  train=95.0%  val=97.0% ★
# Epoch   2/30  loss=0.8192  train=96.7%  val=97.0%
# Epoch   3/30  loss=0.7174  train=96.8%  val=97.0%
# Epoch   4/30  loss=0.7397  train=96.3%  val=97.0%
# Epoch   5/30  loss=0.5679  train=96.7%  val=97.0%
# Epoch   6/30  loss=0.6657  train=95.7%  val=97.0%
# Epoch   7/30  loss=0.8183  train=93.3%  val=97.0%
# Epoch   8/30  loss=0.6505  train=96.5%  val=2.1%
# Epoch   9/30  loss=0.7184  train=95.7%  val=96.8%
# Epoch  10/30  loss=0.7018  train=96.7%  val=97.0%
# Epoch  11/30  loss=0.5788  train=96.8%  val=97.0%
# Epoch  12/30  loss=0.5263  train=96.8%  val=97.0%
# Epoch  13/30  loss=0.4797  train=96.8%  val=97.0%
# Epoch  14/30  loss=0.4758  train=96.8%  val=97.0%
# Epoch  15/30  loss=0.5488  train=96.9%  val=97.0%
# Epoch  16/30  loss=0.4907  train=96.7%  val=97.0%
# Epoch  17/30  loss=0.3383  train=96.8%  val=97.0%
# Epoch  18/30  loss=0.4313  train=96.9%  val=97.0%
# Epoch  19/30  loss=0.4165  train=96.9%  val=97.0%
# Epoch  20/30  loss=0.2773  train=96.9%  val=97.0%
# Epoch  21/30  loss=0.2663  train=96.9%  val=97.0%
# Epoch  22/30  loss=0.3539  train=96.9%  val=97.0%
# Epoch  23/30  loss=0.2963  train=96.9%  val=97.0%
# Epoch  24/30  loss=0.2419  train=97.0%  val=97.0%
# Epoch  25/30  loss=0.2450  train=97.1%  val=97.0%
# Epoch  26/30  loss=0.2814  train=97.1%  val=97.0%
# Epoch  27/30  loss=0.2514  train=97.2%  val=97.0%
# Epoch  28/30  loss=0.2896  train=97.2%  val=97.0%
# Epoch  29/30  loss=0.1849  train=97.2%  val=97.0%
# Epoch  30/30  loss=0.3008  train=97.2%  val=97.0%
#
# Best val accuracy: 96.95%

# %% [markdown]
# ## 10. Training Curves

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
ax1.plot(history["tr_loss"], color="#e74c3c", label="Train loss")
ax1.set_title("Loss"); ax1.set_xlabel("Epoch"); ax1.legend(); ax1.grid(alpha=0.3)
ax2.plot(history["tr_acc"], color="#3498db", label="Train")
ax2.plot(history["va_acc"], color="#2ecc71", label="Val")
ax2.set_title("Accuracy (%)"); ax2.set_xlabel("Epoch"); ax2.legend(); ax2.grid(alpha=0.3)
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 11. Per-class Accuracy

# %%
model = MazeCellCNN.load(MODEL_PATH)

all_preds, all_true = [], []
with torch.no_grad():
    for x, y in DataLoader(MazeCellDataset(patches, labels), batch_size=256):
        all_preds.append(model(x).argmax(1).numpy())
        all_true.append(y.numpy())

preds = np.concatenate(all_preds)
true  = np.concatenate(all_true)
print(f"Overall accuracy: {(preds == true).mean()*100:.2f}%\n")
print(f"{'Class':<12} {'Acc':>7}  {'Samples':>8}")
print("-" * 32)
for i, name in enumerate(CLASS_NAMES):
    mask = true == i
    if not mask.any(): continue
    print(f"{name:<12} {(preds[mask]==i).mean()*100:>6.1f}%  {mask.sum():>8d}")
# Out:
# Overall accuracy: 96.79%
#
# Class            Acc   Samples
# --------------------------------
# path           96.9%      7994
# death_pit     100.0%       183
# confusion       0.0%         4
# tp_orange       0.0%         3
# tp_green        0.0%         2
# tp_purple       0.0%         2
# start           0.0%         2
# goal            0.0%         2

# %% [markdown]
# ## 12. Visualise CNN Predictions

# %%
def predict_full_maze(maze_path, model):
    loader = MazeLoader(maze_path)
    h, w   = loader.maze_height_cells, loader.maze_width_cells
    grid   = np.zeros((h, w, 3), dtype=np.uint8)
    model.eval()
    for r in range(h):
        for c in range(w):
            y0  = r * CELL_SIZE + WALL_THICK
            x0  = c * CELL_SIZE + WALL_THICK
            bgr = loader.bgr[y0:y0+INNER_SIZE, x0:x0+INNER_SIZE]
            cls, _ = model.predict(bgr)
            grid[r, c] = CLASS_COLOURS[cls]
    return grid


EVAL_MAZE = next((m for m in MAZE_FILES if os.path.exists(m)), None)
if EVAL_MAZE:
    grid = predict_full_maze(EVAL_MAZE, model)
    fig, axes = plt.subplots(1, 2, figsize=(14, 7))
    axes[0].imshow(Image.open(EVAL_MAZE)); axes[0].set_title("Original"); axes[0].axis("off")
    axes[1].imshow(grid, interpolation="nearest")
    axes[1].set_title("CNN predictions"); axes[1].axis("off")
    legend_p = [mpatches.Patch(color=np.array(c)/255, label=n)
                for c, n in zip(CLASS_COLOURS, CLASS_NAMES)]
    axes[1].legend(handles=legend_p, loc="upper right", fontsize=7, ncol=2)
    plt.tight_layout(); plt.show()

# %%
# ── Cell 13: Verify fire cluster pivots ──────────────────────────────────────
from environment import MazeEnvironment

print(f"Loading environment from {EVAL_MAZE}...")
env = MazeEnvironment(EVAL_MAZE)

# Draw all 4 rotation states side by side
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
fig.suptitle("Fire cluster rotation states — pivot shown as ★", fontsize=11)

maze_base = np.array(Image.open(EVAL_MAZE).convert("RGB"))

for rot_idx in range(4):
    ax  = axes[rot_idx]
    img = maze_base.copy()

    fire_state = env._fire_rotation_states[rot_idx]

    # Draw fire cells (red)
    for r, c in fire_state:
        y0 = r * 16 + 4;  y1 = y0 + 8
        x0 = c * 16 + 4;  x1 = x0 + 8
        img[y0:y1, x0:x1] = [220, 40, 40]

    ax.imshow(img, interpolation="nearest")
    ax.set_title(f"State {rot_idx}", fontsize=9)
    ax.axis("off")

    # Mark pivot cells (bright yellow dot)
    for cluster in env.initial_fire_clusters:
        if len(cluster) <= 1:
            continue
        rows = [r for r, _ in cluster]; cols = [c for _, c in cluster]
        cr = sum(rows) / len(rows);     cc  = sum(cols) / len(cols)
        pr, pc = min(cluster, key=lambda cell: (cell[0]-cr)**2 + (cell[1]-cc)**2)
        py = pr * 16 + 8;  px = pc * 16 + 8
        ax.plot(px, py, "*", color="yellow", markersize=8, markeredgecolor="black",
                markeredgewidth=0.5, zorder=5)

plt.tight_layout(); plt.show()

print(f"\nCluster summary ({len(env.initial_fire_clusters)} clusters):")
for i, cluster in enumerate(env.initial_fire_clusters):
    rows = [r for r, _ in cluster]; cols = [c for _, c in cluster]
    cr = sum(rows)/len(rows); cc = sum(cols)/len(cols)
    pr, pc = min(cluster, key=lambda cell: (cell[0]-cr)**2 + (cell[1]-cc)**2)
    print(f"  Cluster {i:2d}: {len(cluster):2d} cells  pivot=({pr},{pc})  "
          f"bbox=rows[{min(rows)}-{max(rows)}] cols[{min(cols)}-{max(cols)}]")

# %% [markdown]
# ## 13. CnnMazeLoader — Drop-in for `environment.py`
#
# Swap this into `environment.py` to use the CNN for hazard detection:
#
# ```python
# from maze_cnn import CnnMazeLoader
# # in MazeEnvironment.__init__:
# self.loader = CnnMazeLoader(maze_image_path)
# ```
#
# > **Note on `tp_red`:** The environment currently has no `teleport_red` group in `MazeLoader`.
# > After swapping in `CnnMazeLoader`, add this to `MazeEnvironment.__init__` to handle red teleports:
# >
# > ```python
# > self.teleport_red = set(map(tuple, self.loader.teleport_red))
# > # then add to teleport_map loop and all_hazard_cells
# > ```

# %%
class CnnMazeLoader(MazeLoader):
    """
    Drop-in for MazeLoader. Uses CNN; falls back to color classifier on low confidence.
    Adds teleport_red as a new hazard list.
    """
    _CLS_MAP = {
        LABEL_FIRE:  "death_pit",
        LABEL_CONF:  "confusion",
        LABEL_TPO:   "teleport_orange",
        LABEL_TPG:   "teleport_green",
        LABEL_TPP:   "teleport_purple",
        LABEL_TPR:   "teleport_red",
    }
    CONF_THRESHOLD = 0.70

    def __init__(self, image_path, model_path=MODEL_PATH, **kwargs):
        super().__init__(image_path, **kwargs)
        self.teleport_red = []   # new hazard list
        if os.path.exists(model_path):
            self._cnn = MazeCellCNN.load(model_path)
            print(f"[CnnMazeLoader] CNN loaded from {model_path}")
        else:
            self._cnn = None
            print(f"[CnnMazeLoader] no model found — color classifier only")

    def classify_cell_template(self, r, c):
        if self._cnn is not None:
            patch = self.cell_interior_bgr(r, c)
            cls, conf = self._cnn.predict(patch)
            if cls in self._CLS_MAP and conf >= self.CONF_THRESHOLD:
                return self._CLS_MAP[cls]
        return super().classify_cell_template(r, c)

    def detect_hazards(self):
        summary = super().detect_hazards()
        # Re-scan for tp_red (not in parent's detect_hazards)
        for r in range(self.maze_height_cells):
            for c in range(self.maze_width_cells):
                if self._cnn is not None:
                    patch = self.cell_interior_bgr(r, c)
                    cls, conf = self._cnn.predict(patch)
                    if cls == LABEL_TPR and conf >= self.CONF_THRESHOLD:
                        self.teleport_red.append((r, c))
        summary["teleport_red"] = len(self.teleport_red)
        return summary


if EVAL_MAZE:
    cnn_loader = CnnMazeLoader(EVAL_MAZE)
    summary    = cnn_loader.detect_hazards()
    print("\nHazard summary:")
    for k, v in summary.items():
        print(f"  {k:<20}: {v}")
# Out:
# [CnnMazeLoader] CNN loaded from maze_cnn.pt
# searching 64×64 cells for hazards
# Found 67 hazardous cells
#
# Hazard summary:
#   death_pits          : 56
#   confusion           : 2
#   teleport_purple     : 2
#   teleport_orange     : 5
#   teleport_green      : 2
#   start_pos           : (1025, 521)
#   goal_pos            : (0, 505)
#   teleport_red        : 0

# %% [markdown]
# ## 14. Test the Map with Your Agent
#
# This cell runs a single episode of your trained neuroevolution agent on the maze,
# using `CnnMazeLoader` for detection, and visualises the path it takes.

# %%
import sys
sys.path.insert(0, ".")  # make sure local files are importable

from environment import MazeEnvironment, Action
from maze_agent  import NeuralController, EvolutionaryAgent, configure, evaluate_fitness

AGENT_WEIGHTS = "best_weights.npy"   # saved by live_viz.py training
TEST_MAZE     = EVAL_MAZE
MAX_TURNS     = 10_000

if not os.path.exists(AGENT_WEIGHTS):
    print(f"⚠ No weights found at '{AGENT_WEIGHTS}' — run training first.")
else:
    # ── 1. Build environment with CNN loader ─────────────────────────────────
    # Monkey-patch MazeLoader so MazeEnvironment picks up CnnMazeLoader
    import maze as _maze_module
    _original_loader = _maze_module.MazeLoader
    _maze_module.MazeLoader = CnnMazeLoader

    env = MazeEnvironment(TEST_MAZE)
    configure(env.start_cell, env.goal_cell)

    _maze_module.MazeLoader = _original_loader   # restore

    print(f"Start: {env.start_cell}  Goal: {env.goal_cell}")
    print(f"Death pits: {len(env.death_pits)}  "
          f"Confusion: {len(env.confusion_pads)}  "
          f"Teleports: {len(env.teleport_map)}")

    # ── 2. Load best weights and run one episode ──────────────────────────────
    ctrl = NeuralController()
    ctrl.load(AGENT_WEIGHTS)

    from maze_agent import GOAL_CELL, START_CELL
    fitness, agent = evaluate_fitness(
        ctrl, env,
        goal_cell=GOAL_CELL, start_cell=START_CELL,
        episodes=1, max_turns=MAX_TURNS,
        epsilon=0.0, verbose=True,
    )
    stats = env.get_episode_stats()
    print(f"\nFitness: {fitness:+.0f}")
    print(f"Goal reached: {stats['goal_reached']}")
    print(f"Turns: {stats['turns_taken']}  Deaths: {stats['deaths']}  "
          f"Explored: {stats['cells_explored']} cells")

    # ── 3. Visualise path ─────────────────────────────────────────────────────
    maze_img = np.array(Image.open(TEST_MAZE).convert("RGB"))
    overlay  = maze_img.copy()

    path = agent.memory.path
    n    = max(1, len(path) - 1)
    for i, (r, c) in enumerate(path):
        t  = i / n
        py = r * CELL_SIZE + CELL_SIZE // 2
        px = c * CELL_SIZE + CELL_SIZE // 2
        colour = (int(30+100*t), int(80+175*t), 255)
        cv2.circle(overlay, (px, py), 2, colour, -1)

    # Mark start and goal
    sr, sc_ = env.start_cell
    gr, gc_ = env.goal_cell
    cv2.circle(overlay, (sc_*CELL_SIZE+8, sr*CELL_SIZE+8), 6, (0,230,100), -1)
    cv2.circle(overlay, (gc_*CELL_SIZE+8, gr*CELL_SIZE+8), 6, (0,210,255), -1)

    fig, axes = plt.subplots(1, 2, figsize=(14, 7))
    axes[0].imshow(maze_img);  axes[0].set_title("Original");       axes[0].axis("off")
    axes[1].imshow(overlay);   axes[1].set_title("Agent path");      axes[1].axis("off")
    plt.suptitle(f"Fitness: {fitness:+.0f}  |  Turns: {stats['turns_taken']}  "
                 f"Deaths: {stats['deaths']}  Goal: {stats['goal_reached']}",
                 fontsize=10)
    plt.tight_layout(); plt.show()
# Out:
# searching 64×64 cells for hazards
# Found 67 hazardous cells
# Start: (63, 32)  Goal: (0, 31)
# Death pits: 50  Confusion: 2  Teleports: 15
#
#   ── Episode 1/1  start=(63, 32)  goal=(0, 31) ──
#   t00001 ↑  pos=(63, 32)  dist= 64  WALL×1
#   t00004 ←  pos=(62, 33)  dist= 64  WALL×1
#   t00011 →  pos=(62, 33)  dist= 64  WALL×1
#   t00012 →  pos=(62, 33)  dist= 64  WALL×1
#   t00013 →  pos=(62, 33)  dist= 64  WALL×1
#   t00014 ↑  pos=(62, 33)  dist= 64  WALL×1
#   t00015 →  pos=(62, 33)  dist= 64  WALL×1
#   t00016 →  pos=(62, 33)  dist= 64  WALL×1
#   t00018 →  pos=(63, 33)  dist= 65  WALL×1
#   t00019 →  pos=(63, 33)  dist= 65  WALL×1
#   t00020 →  pos=(63, 33)  dist= 65  WALL×1
#   t00023 ↑  pos=(63, 31)  dist= 63  WALL×1
#   t00026 →  pos=(63, 33)  dist= 65  WALL×1
#   t00027 →  pos=(63, 33)  dist= 65  WALL×1
#   t00028 →  pos=(63, 33)  dist= 65  WALL×1
#   t00032 ↑  pos=(63, 30)  dist= 64  WALL×1
#   t00034 ↑  pos=(63, 31)  dist= 63  WALL×1
#   t00035 ↑  pos=(63, 31)  dist= 63  WALL×1
#   t00036 ↑  pos=(63, 31)  dist= 63  WALL×1
#   t00040 ←  pos=(62, 29)  dist= 64  WALL×1
#   t00046 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00047 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00048 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00050 ↑  pos=(61, 28)  dist= 64  WALL×1
#   t00052 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00053 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00054 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00056 ↓  pos=(61, 30)  dist= 62  WALL×1
#   t00058 ↓  pos=(61, 31)  dist= 61  WALL×1
#   t00061 ↑  pos=(60, 30)  dist= 61  WALL×1
#   t00063 ↑  pos=(60, 31)  dist= 60  WALL×1
#   t00064 →  pos=(60, 31)  dist= 60  WALL×1
#   t00065 →  pos=(60, 31)  dist= 60  WALL×1
#   t00067 →  pos=(61, 31)  dist= 61  WALL×1
#   t00068 →  pos=(61, 31)  dist= 61  WALL×1
#   t00069 →  pos=(61, 31)  dist= 61  WALL×1
#   t00072 ←  pos=(60, 30)  dist= 61  WALL×1
#   t00074 →  pos=(60, 31)  dist= 60  WALL×1
#   t00075 →  pos=(60, 31)  dist= 60  WALL×1
#   t00076 →  pos=(60, 31)  dist= 60  WALL×1
#   t00082 ↑  pos=(62, 30)  dist= 63  WALL×1
#   t00092 ↑  pos=(62, 31)  dist= 62  WALL×1
#   t00097 ↑  pos=(61, 32)  dist= 62  WALL×1
#   t00099 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00100 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00101 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00103 ↓  pos=(61, 34)  dist= 64  WALL×1
#   t00106 ↑  pos=(60, 33)  dist= 62  WALL×1
#   t00107 ↑  pos=(60, 33)  dist= 62  WALL×1
#   t00108 ↑  pos=(60, 33)  dist= 62  WALL×1
#   t00110 ↓  pos=(60, 32)  dist= 61  WALL×1
#   t00112 ←  pos=(59, 32)  dist= 60  WALL×1
#   t00117 ↑  pos=(59, 32)  dist= 60  WALL×1
#   t00118 →  pos=(59, 32)  dist= 60  WALL×1
#   t00119 →  pos=(59, 32)  dist= 60  WALL×1
#   t00123 ↑  pos=(60, 34)  dist= 63  WALL×1
#   t00124 →  pos=(60, 34)  dist= 63  WALL×1
#   t00125 →  pos=(60, 34)  dist= 63  WALL×1
#   t00127 →  pos=(61, 34)  dist= 64  WALL×1
#   t00128 →  pos=(61, 34)  dist= 64  WALL×1
#   t00129 →  pos=(61, 34)  dist= 64  WALL×1
#   t00132 ←  pos=(61, 32)  dist= 62  WALL×1
#   t00134 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00135 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00136 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00137 ↓  pos=(61, 33)  dist= 63  WALL×1
#   t00138 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00139 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00142 ↓  pos=(62, 32)  dist= 63  WALL×1
#   t00145 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00146 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00147 ↑  pos=(61, 33)  dist= 63  WALL×1
#   t00150 ←  pos=(62, 31)  dist= 62
#   t00151 ↓  pos=(62, 31)  dist= 62  WALL×1
#   t00153 →  pos=(62, 32)  dist= 63  WALL×1
#   t00154 →  pos=(62, 32)  dist= 63  WALL×1
#   t00155 →  pos=(62, 32)  dist= 63  WALL×1
#   t00158 ↓  pos=(62, 30)  dist= 63  WALL×1
#   t00161 →  pos=(62, 32)  dist= 63  WALL×1
#   t00162 →  pos=(62, 32)  dist= 63  WALL×1
#   t00163 →  pos=(62, 32)  dist= 63  WALL×1
#   t00169 ↑  pos=(63, 28)  dist= 66  WALL×1
#   t00172 ←  pos=(62, 29)  dist= 64  WALL×1
#   t00173 ←  pos=(62, 29)  dist= 64  WALL×1
#   t00177 →  pos=(62, 32)  dist= 63  WALL×1
#   t00178 →  pos=(62, 32)  dist= 63  WALL×1
#   t00179 →  pos=(62, 32)  dist= 63  WALL×1
#   t00187 ←  pos=(62, 27)  dist= 66  WALL×1
#   t00188 ↓  pos=(62, 27)  dist= 66  WALL×1
#   t00191 ←  pos=(60, 27)  dist= 64  WALL×1
#   t00197 ↑  pos=(59, 27)  dist= 63  WALL×1
#   t00198 ↑  pos=(59, 27)  dist= 63  WALL×1
#   t00199 ↑  pos=(59, 27)  dist= 63  WALL×1
#   t00200 ←  pos=(59, 27)  dist= 63  WALL×1
#   t00206 ↑  pos=(59, 28)  dist= 62  WALL×1
#   t00207 →  pos=(59, 28)  dist= 62  WALL×1
#   t00208 →  pos=(59, 28)  dist= 62  WALL×1
#   t00214 ↑  pos=(59, 29)  dist= 61  WALL×1
#   t00216 ↑  pos=(59, 30)  dist= 60  WALL×1
#   t00219 ←  pos=(58, 31)  dist= 58  WALL×1
#   t00224 ↑  pos=(58, 31)  dist= 58  WALL×1
#   t00226 ↑  pos=(58, 32)  dist= 59  WALL×1
#   t00227 ↑  pos=(58, 32)  dist= 59  WALL×1
#   t00228 ↑  pos=(58, 32)  dist= 59  WALL×1
#   t00236 ↑  pos=(58, 33)  dist= 60  WALL×1
#   t00237 ↑  pos=(58, 33)  dist= 60  WALL×1
#   t00238 ↑  pos=(58, 33)  dist= 60  WALL×1
#   t00239 →  pos=(58, 33)  dist= 60  WALL×1
#   t00240 →  pos=(58, 33)  dist= 60  WALL×1
#   t00241 →  pos=(58, 33)  dist= 60  WALL×1
#   t00250 ↑  pos=(58, 34)  dist= 61
#   t00256 ↑  pos=(57, 34)  dist= 60  WALL×1
#   t00257 ↑  pos=(57, 34)  dist= 60  WALL×1
#   t00258 ↑  pos=(57, 34)  dist= 60  WALL×1
#   t00259 ←  pos=(57, 34)  dist= 60  WALL×1
#   t00260 ↑  pos=(57, 34)  dist= 60  WALL×1
#   t00261 ↑  pos=(57, 34)  dist= 60  WALL×1
#   t00263 ↓  pos=(57, 35)  dist= 61  WALL×1
#   t00264 →  pos=(57, 35)  dist= 61  WALL×1
#   t00265 →  pos=(57, 35)  dist= 61  WALL×1
#   t00267 ↑  pos=(56, 35)  dist= 60  WALL×1
#   t00269 ↓  pos=(56, 36)  dist= 61  WALL×1
#   t00270 ↑  pos=(56, 36)  dist= 61  WALL×1
#   t00271 ↑  pos=(56, 36)  dist= 61  WALL×1
#   t00273 ↓  pos=(56, 37)  dist= 62  WALL×1
#   t00276 ↑  pos=(55, 36)  dist= 60  WALL×1
#   t00277 →  pos=(55, 37)  dist= 61  💀 DEAD→respawn
#   t00279 →  pos=(63, 33)  dist= 65  WALL×1
#   t00280 →  pos=(63, 33)  dist= 65  WALL×1
#   t00281 →  pos=(63, 33)  dist= 65  WALL×1
#   t00288 ↑  pos=(63, 27)  dist= 67  WALL×1
#   t00295 →  pos=(63, 33)  dist= 65  WALL×1
#   t00296 →  pos=(63, 33)  dist= 65  WALL×1
#   t00297 →  pos=(63, 33)  dist= 65  WALL×1
#   t00300 ←  pos=(63, 30)  dist= 64
#   t00305 ↑  pos=(63, 26)  dist= 68  WALL×1
#   t00306 ↑  pos=(63, 26)  dist= 68  WALL×1
#   t00307 ↑  pos=(63, 26)  dist= 68  WALL×1
#   t00309 ↑  pos=(63, 25)  dist= 69  WALL×1
#   t00310 ↑  pos=(63, 25)  dist= 69  WALL×1
#   t00311 ↑  pos=(63, 25)  dist= 69  WALL×1
#   t00314 ←  pos=(62, 24)  dist= 69  WALL×1
#   t00319 →  pos=(62, 24)  dist= 69  WALL×1
#   t00320 →  pos=(62, 24)  dist= 69  WALL×1
#   t00321 →  pos=(62, 24)  dist= 69  WALL×1
#   t00323 ↑  pos=(61, 24)  dist= 68  WALL×1
#   t00324 ↑  pos=(61, 24)  dist= 68  WALL×1
#   t00325 ↑  pos=(61, 24)  dist= 68  WALL×1
#   t00327 ↑  pos=(61, 23)  dist= 69  WALL×1
#   t00329 ↑  pos=(61, 24)  dist= 68  WALL×1
#   t00330 ↑  pos=(61, 24)  dist= 68  WALL×1
#   t00331 ↑  pos=(61, 24)  dist= 68  WALL×1
#   t00332 →  pos=(61, 24)  dist= 68  WALL×1
#   t00333 →  pos=(61, 24)  dist= 68  WALL×1
#   t00334 →  pos=(61, 24)  dist= 68  WALL×1
#   t00339 ↑  pos=(61, 22)  dist= 70  WALL×1
#   t00340 →  pos=(61, 22)  dist= 70  WALL×1
#   t00341 →  pos=(61, 22)  dist= 70  WALL×1
#   t00343 ↑  pos=(61, 21)  dist= 71  WALL×1
#   t00345 →  pos=(61, 22)  dist= 70  WALL×1
#   t00346 →  pos=(61, 22)  dist= 70  WALL×1
#   t00347 →  pos=(61, 22)  dist= 70  WALL×1
#   t00350 ↑  pos=(62, 22)  dist= 71
#   t00352 ←  pos=(62, 21)  dist= 72  WALL×1
#   t00353 ↑  pos=(62, 21)  dist= 72  WALL×1
#   t00360 →  pos=(61, 22)  dist= 70  WALL×1
#   t00361 →  pos=(61, 22)  dist= 70  WALL×1
#   t00362 →  pos=(61, 22)  dist= 70  WALL×1
#   t00365 ↑  pos=(61, 20)  dist= 72  WALL×1
#   t00367 ↑  pos=(61, 21)  dist= 71  WALL×1
#   t00368 ↑  pos=(61, 21)  dist= 71  WALL×1
#   t00369 ↑  pos=(61, 21)  dist= 71  WALL×1
#   t00370 ↓  pos=(61, 21)  dist= 71  WALL×1
#   t00371 ↑  pos=(61, 21)  dist= 71  WALL×1
#   t00372 ↑  pos=(61, 21)  dist= 71  WALL×1
#   t00374 ↓  pos=(61, 20)  dist= 72  WALL×1
#   t00376 ↑  pos=(61, 21)  dist= 71  WALL×1
#   t00377 ↑  pos=(61, 21)  dist= 71  WALL×1
#   t00378 ↑  pos=(61, 21)  dist= 71  WALL×1
#   t00380 ←  pos=(29, 1)  dist= 59  🌀 TELEPORT→(29, 1)
#   t00381 ↓  pos=(29, 1)  dist= 59  WALL×1
#   t00383 ↑  pos=(28, 1)  dist= 58  WALL×1
#   t00384 →  pos=(28, 1)  dist= 58  WALL×1
#   t00385 →  pos=(28, 1)  dist= 58  WALL×1
#   t00389 ↓  pos=(30, 0)  dist= 61  WALL×1
#   t00393 ↓  pos=(30, 1)  dist= 60  WALL×1
#   t00394 ↑  pos=(30, 1)  dist= 60  WALL×1
#   t00398 ↓  pos=(32, 2)  dist= 61  WALL×1
#   t00400 ↑  pos=(30, 2)  dist= 59
#   t00401 ↑  pos=(30, 2)  dist= 59  WALL×1
#   t00402 ↑  pos=(30, 2)  dist= 59  WALL×1
#   t00403 ↑  pos=(30, 2)  dist= 59  WALL×1
#   t00406 ↓  pos=(31, 3)  dist= 59  WALL×1
#   t00410 ↑  pos=(30, 3)  dist= 58  WALL×1
#   t00411 ↑  pos=(30, 3)  dist= 58  WALL×1
#   t00412 ↑  pos=(30, 3)  dist= 58  WALL×1
#   t00413 →  pos=(30, 3)  dist= 58  WALL×1
#   t00414 →  pos=(30, 3)  dist= 58  WALL×1
#   t00415 →  pos=(30, 3)  dist= 58  WALL×1
#   t00417 →  pos=(31, 3)  dist= 59  WALL×1
#   t00418 →  pos=(31, 3)  dist= 59  WALL×1
#   t00419 →  pos=(31, 3)  dist= 59  WALL×1
#   t00420 ←  pos=(31, 3)  dist= 59  WALL×1
#   t00421 →  pos=(31, 3)  dist= 59  WALL×1
#   t00422 →  pos=(31, 3)  dist= 59  WALL×1
#   t00426 ←  pos=(31, 2)  dist= 60  WALL×1
#   t00428 ↑  pos=(30, 2)  dist= 59  WALL×1
#   t00429 ↑  pos=(30, 2)  dist= 59  WALL×1
#   t00430 ↑  pos=(30, 2)  dist= 59  WALL×1
#   t00433 ←  pos=(32, 2)  dist= 61  WALL×1
#   t00436 ↓  pos=(32, 4)  dist= 59  WALL×1
#   t00442 ↑  pos=(31, 4)  dist= 58  WALL×1
#   t00444 ↓  pos=(31, 5)  dist= 57  WALL×1
#   t00445 ↑  pos=(31, 5)  dist= 57  WALL×1
#   t00447 ↓  pos=(31, 6)  dist= 56  WALL×1
#   t00449 ↑  pos=(30, 6)  dist= 55  WALL×1
#   t00450 →  pos=(30, 6)  dist= 55  WALL×1
#   t00452 ↑  pos=(30, 5)  dist= 56  WALL×1
#   t00453 ↑  pos=(30, 5)  dist= 56  WALL×1
#   t00454 ↑  pos=(30, 5)  dist= 56  WALL×1
#   t00458 ↑  pos=(28, 4)  dist= 55  WALL×1
#   t00459 →  pos=(28, 4)  dist= 55  WALL×1
#   t00460 →  pos=(28, 4)  dist= 55  WALL×1
#   t00462 ↑  pos=(28, 3)  dist= 56  WALL×1
#   t00464 →  pos=(28, 4)  dist= 55  WALL×1
#   t00465 →  pos=(28, 4)  dist= 55  WALL×1
#   t00466 →  pos=(28, 4)  dist= 55  WALL×1
#   t00468 ←  pos=(29, 4)  dist= 56  WALL×1
#   t00477 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00478 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00479 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00480 →  pos=(28, 5)  dist= 54  WALL×1
#   t00481 →  pos=(28, 5)  dist= 54  WALL×1
#   t00482 →  pos=(28, 5)  dist= 54  WALL×1
#   t00484 →  pos=(29, 5)  dist= 55  WALL×1
#   t00485 →  pos=(29, 5)  dist= 55  WALL×1
#   t00486 →  pos=(29, 5)  dist= 55  WALL×1
#   t00488 ←  pos=(28, 5)  dist= 54  WALL×1
#   t00489 →  pos=(28, 5)  dist= 54  WALL×1
#   t00490 →  pos=(28, 5)  dist= 54  WALL×1
#   t00492 ↓  pos=(29, 5)  dist= 55  WALL×1
#   t00493 →  pos=(29, 5)  dist= 55  WALL×1
#   t00494 →  pos=(29, 5)  dist= 55  WALL×1
#   t00498 ↓  pos=(28, 3)  dist= 56  WALL×1
#   t00500 →  pos=(28, 4)  dist= 55  WALL×1
#   t00501 →  pos=(28, 4)  dist= 55  WALL×1
#   t00502 →  pos=(28, 4)  dist= 55  WALL×1
#   t00504 ←  pos=(28, 2)  dist= 57  💀 DEAD→respawn
#   t00506 →  pos=(63, 33)  dist= 65  WALL×1
#   t00507 →  pos=(63, 33)  dist= 65  WALL×1
#   t00508 →  pos=(63, 33)  dist= 65  WALL×1
#   t00516 ←  pos=(61, 28)  dist= 64  WALL×1
#   t00518 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00519 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00520 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00525 ←  pos=(61, 27)  dist= 65  WALL×1
#   t00526 →  pos=(61, 27)  dist= 65  WALL×1
#   t00527 →  pos=(61, 27)  dist= 65  WALL×1
#   t00530 ↓  pos=(62, 28)  dist= 65  WALL×1
#   t00533 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00534 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00535 ↑  pos=(61, 29)  dist= 63  WALL×1
#   t00543 ←  pos=(63, 24)  dist= 70  WALL×1
#   t00545 ↑  pos=(63, 25)  dist= 69  WALL×1
#   t00546 ↑  pos=(63, 25)  dist= 69  WALL×1
#   t00547 ↑  pos=(63, 25)  dist= 69  WALL×1
#   t00550 ↑  pos=(61, 24)  dist= 68
#   t00560 ↑  pos=(61, 23)  dist= 69  WALL×1
#   t00561 ↑  pos=(61, 23)  dist= 69  WALL×1
#   t00562 ↑  pos=(61, 23)  dist= 69  WALL×1
#   t00565 ←  pos=(63, 23)  dist= 71  WALL×1
#   t00566 →  pos=(63, 23)  dist= 71  WALL×1
#   t00567 →  pos=(63, 23)  dist= 71  WALL×1
#   t00572 ↑  pos=(63, 21)  dist= 73  WALL×1
#   t00574 →  pos=(63, 22)  dist= 72  WALL×1
#   t00575 →  pos=(63, 22)  dist= 72  WALL×1
#   t00576 →  pos=(63, 22)  dist= 72  WALL×1
#   t00581 ↑  pos=(62, 19)  dist= 74  WALL×1
#   t00585 ↑  pos=(62, 20)  dist= 73  WALL×1
#   t00586 →  pos=(62, 20)  dist= 73  WALL×1
#   t00587 →  pos=(62, 20)  dist= 73  WALL×1
#   t00589 ←  pos=(63, 20)  dist= 74  WALL×1
#   t00592 →  pos=(63, 22)  dist= 72  WALL×1
#   t00593 →  pos=(63, 22)  dist= 72  WALL×1
#   t00594 →  pos=(63, 22)  dist= 72  WALL×1
#   t00599 ←  pos=(29, 1)  dist= 59  🌀 TELEPORT→(29, 1)
#   t00600 ↑  pos=(28, 1)  dist= 58
#   t00601 →  pos=(28, 1)  dist= 58  WALL×1
#   t00602 →  pos=(28, 1)  dist= 58  WALL×1
#   t00603 →  pos=(28, 1)  dist= 58  WALL×1
#   t00604 ↓  pos=(32, 31)  dist= 32  🌀 TELEPORT→(32, 31)
#   t00605 →  pos=(33, 52)  dist= 54  🌀 TELEPORT→(33, 52)
#   t00606 ↓  pos=(33, 52)  dist= 54  WALL×1
#   t00608 ↓  pos=(33, 53)  dist= 55  WALL×1
#   t00610 ↓  pos=(33, 54)  dist= 56  WALL×1
#   t00611 →  pos=(33, 54)  dist= 56  WALL×1
#   t00612 →  pos=(33, 54)  dist= 56  WALL×1
#   t00615 →  pos=(33, 54)  dist= 56  WALL×1
#   t00616 →  pos=(33, 54)  dist= 56  WALL×1
#   t00617 →  pos=(33, 54)  dist= 56  WALL×1
#   t00619 ↑  pos=(32, 54)  dist= 55  WALL×1
#   t00620 ↑  pos=(32, 54)  dist= 55  WALL×1
#   t00621 ↑  pos=(32, 54)  dist= 55  WALL×1
#   t00623 ↓  pos=(32, 53)  dist= 54  WALL×1
#   t00625 ←  pos=(31, 53)  dist= 53  WALL×1
#   t00627 ←  pos=(32, 53)  dist= 54  WALL×1
#   t00630 →  pos=(33, 54)  dist= 56  WALL×1
#   t00631 →  pos=(33, 54)  dist= 56  WALL×1
#   t00632 →  pos=(33, 54)  dist= 56  WALL×1
#   t00634 →  pos=(32, 54)  dist= 55  WALL×1
#   t00636 →  pos=(33, 54)  dist= 56  WALL×1
#   t00637 →  pos=(33, 54)  dist= 56  WALL×1
#   t00638 →  pos=(33, 54)  dist= 56  WALL×1
#   t00640 ←  pos=(58, 16)  dist= 73  🌀 TELEPORT→(58, 16)
#   t00641 ↑  pos=(58, 16)  dist= 73  WALL×1
#   t00643 ↑  pos=(58, 17)  dist= 72  WALL×1
#   t00644 →  pos=(58, 17)  dist= 72  WALL×1
#   t00645 →  pos=(58, 17)  dist= 72  WALL×1
#   t00646 ↓  pos=(58, 17)  dist= 72  WALL×1
#   t00647 →  pos=(58, 17)  dist= 72  WALL×1
#   t00648 →  pos=(58, 17)  dist= 72  WALL×1
#   t00649 ←  pos=(59, 15)  dist= 75  🌀 TELEPORT→(59, 15)
#   t00650 ↓  pos=(60, 15)  dist= 76
#   t00651 ←  pos=(60, 15)  dist= 76  WALL×1
#   t00654 ↑  pos=(60, 18)  dist= 73  🌀 TELEPORT→(60, 18)
#   t00655 ↑  pos=(60, 18)  dist= 73  WALL×1
#   t00656 →  pos=(60, 18)  dist= 73  WALL×1
#   t00657 →  pos=(60, 18)  dist= 73  WALL×1
#   t00659 ←  pos=(61, 18)  dist= 74  WALL×1
#   t00660 ↓  pos=(61, 18)  dist= 74  WALL×1
#   t00661 →  pos=(29, 1)  dist= 59  🌀 TELEPORT→(29, 1)
#   t00662 →  pos=(29, 1)  dist= 59  WALL×1
#   t00663 →  pos=(29, 1)  dist= 59  WALL×1
#   t00664 →  pos=(29, 1)  dist= 59  WALL×1
#   t00667 ↑  pos=(28, 0)  dist= 59  WALL×1
#   t00669 ↓  pos=(32, 31)  dist= 32  🌀 TELEPORT→(32, 31)
#   t00670 ↓  pos=(32, 31)  dist= 32  WALL×1
#   t00671 ↓  pos=(32, 31)  dist= 32  WALL×1
#   t00672 ↓  pos=(32, 31)  dist= 32  WALL×1
#   t00673 ↑  pos=(31, 31)  dist= 31  💀 DEAD→respawn
#   t00675 →  pos=(63, 33)  dist= 65  WALL×1
#   t00676 →  pos=(63, 33)  dist= 65  WALL×1
#   t00677 →  pos=(63, 33)  dist= 65  WALL×1
#   t00690 ←  pos=(61, 23)  dist= 69  WALL×1
#   t00691 ↑  pos=(61, 23)  dist= 69  WALL×1
#   t00692 ↑  pos=(61, 23)  dist= 69  WALL×1
#   t00698 ←  pos=(29, 1)  dist= 59  🌀 TELEPORT→(29, 1)
#   t00699 →  pos=(29, 1)  dist= 59  WALL×1
#   t00700 →  pos=(29, 1)  dist= 59  WALL×1
#   t00701 →  pos=(29, 1)  dist= 59  WALL×1
#   t00702 ←  pos=(29, 1)  dist= 59  WALL×1
#   t00703 →  pos=(29, 1)  dist= 59  WALL×1
#   t00704 →  pos=(29, 1)  dist= 59  WALL×1
#   t00714 ↓  pos=(32, 3)  dist= 60  WALL×1
#   t00717 ↑  pos=(31, 4)  dist= 58  WALL×1
#   t00718 ↑  pos=(31, 4)  dist= 58  WALL×1
#   t00719 ↑  pos=(31, 4)  dist= 58  WALL×1
#   t00721 →  pos=(32, 4)  dist= 59  WALL×1
#   t00722 →  pos=(32, 4)  dist= 59  WALL×1
#   t00723 →  pos=(32, 4)  dist= 59  WALL×1
#   t00727 →  pos=(31, 6)  dist= 56  WALL×1
#   t00729 →  pos=(30, 6)  dist= 55  WALL×1
#   t00730 →  pos=(30, 6)  dist= 55  WALL×1
#   t00731 →  pos=(30, 6)  dist= 55  WALL×1
#   t00735 ←  pos=(29, 4)  dist= 56  WALL×1
#   t00736 ←  pos=(29, 4)  dist= 56  WALL×1
#   t00737 ←  pos=(29, 4)  dist= 56  WALL×1
#   t00739 →  pos=(28, 4)  dist= 55  WALL×1
#   t00740 →  pos=(28, 4)  dist= 55  WALL×1
#   t00741 →  pos=(28, 4)  dist= 55  WALL×1
#   t00744 →  pos=(28, 4)  dist= 55  WALL×1
#   t00745 →  pos=(28, 4)  dist= 55  WALL×1
#   t00746 →  pos=(28, 4)  dist= 55  WALL×1
#   t00749 →  pos=(29, 5)  dist= 55  WALL×1
#   t00750 →  pos=(29, 5)  dist= 55  WALL×1
#   t00751 →  pos=(29, 5)  dist= 55  WALL×1
#   t00754 →  pos=(29, 5)  dist= 55  WALL×1
#   t00755 →  pos=(29, 5)  dist= 55  WALL×1
#   t00756 →  pos=(29, 5)  dist= 55  WALL×1
#   t00759 →  pos=(29, 5)  dist= 55  WALL×1
#   t00760 →  pos=(29, 5)  dist= 55  WALL×1
#   t00761 →  pos=(29, 5)  dist= 55  WALL×1
#   t00763 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00764 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00765 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00767 →  pos=(29, 5)  dist= 55  WALL×1
#   t00768 →  pos=(29, 5)  dist= 55  WALL×1
#   t00769 →  pos=(29, 5)  dist= 55  WALL×1
#   t00771 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00772 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00773 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00775 →  pos=(29, 5)  dist= 55  WALL×1
#   t00776 →  pos=(29, 5)  dist= 55  WALL×1
#   t00777 →  pos=(29, 5)  dist= 55  WALL×1
#   t00780 →  pos=(29, 5)  dist= 55  WALL×1
#   t00781 →  pos=(29, 5)  dist= 55  WALL×1
#   t00782 →  pos=(29, 5)  dist= 55  WALL×1
#   t00785 →  pos=(29, 5)  dist= 55  WALL×1
#   t00786 →  pos=(29, 5)  dist= 55  WALL×1
#   t00787 →  pos=(29, 5)  dist= 55  WALL×1
#   t00790 →  pos=(29, 5)  dist= 55  WALL×1
#   t00791 →  pos=(29, 5)  dist= 55  WALL×1
#   t00792 →  pos=(29, 5)  dist= 55  WALL×1
#   t00794 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00795 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00796 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00798 →  pos=(29, 5)  dist= 55  WALL×1
#   t00799 →  pos=(29, 5)  dist= 55  WALL×1
#   t00800 →  pos=(29, 5)  dist= 55  WALL×1
#   t00802 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00803 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00804 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00806 →  pos=(29, 5)  dist= 55  WALL×1
#   t00807 →  pos=(29, 5)  dist= 55  WALL×1
#   t00808 →  pos=(29, 5)  dist= 55  WALL×1
#   t00810 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00811 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00812 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00814 →  pos=(29, 5)  dist= 55  WALL×1
#   t00815 →  pos=(29, 5)  dist= 55  WALL×1
#   t00816 →  pos=(29, 5)  dist= 55  WALL×1
#   t00818 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00819 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00820 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00822 →  pos=(29, 5)  dist= 55  WALL×1
#   t00823 →  pos=(29, 5)  dist= 55  WALL×1
#   t00824 →  pos=(29, 5)  dist= 55  WALL×1
#   t00827 →  pos=(29, 5)  dist= 55  WALL×1
#   t00828 →  pos=(29, 5)  dist= 55  WALL×1
#   t00829 →  pos=(29, 5)  dist= 55  WALL×1
#   t00832 →  pos=(29, 5)  dist= 55  WALL×1
#   t00833 →  pos=(29, 5)  dist= 55  WALL×1
#   t00834 →  pos=(29, 5)  dist= 55  WALL×1
#   t00836 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00837 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00838 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00840 →  pos=(29, 5)  dist= 55  WALL×1
#   t00841 →  pos=(29, 5)  dist= 55  WALL×1
#   t00842 →  pos=(29, 5)  dist= 55  WALL×1
#   t00844 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00845 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00846 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00848 →  pos=(29, 5)  dist= 55  WALL×1
#   t00849 →  pos=(29, 5)  dist= 55  WALL×1
#   t00850 →  pos=(29, 5)  dist= 55  WALL×1
#   t00852 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00853 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00854 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00856 →  pos=(29, 5)  dist= 55  WALL×1
#   t00857 →  pos=(29, 5)  dist= 55  WALL×1
#   t00858 →  pos=(29, 5)  dist= 55  WALL×1
#   t00861 →  pos=(29, 5)  dist= 55  WALL×1
#   t00862 →  pos=(29, 5)  dist= 55  WALL×1
#   t00863 →  pos=(29, 5)  dist= 55  WALL×1
#   t00866 →  pos=(29, 5)  dist= 55  WALL×1
#   t00867 →  pos=(29, 5)  dist= 55  WALL×1
#   t00868 →  pos=(29, 5)  dist= 55  WALL×1
#   t00871 →  pos=(29, 5)  dist= 55  WALL×1
#   t00872 →  pos=(29, 5)  dist= 55  WALL×1
#   t00873 →  pos=(29, 5)  dist= 55  WALL×1
#   t00875 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00876 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00877 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00879 →  pos=(29, 5)  dist= 55  WALL×1
#   t00880 →  pos=(29, 5)  dist= 55  WALL×1
#   t00881 →  pos=(29, 5)  dist= 55  WALL×1
#   t00883 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00884 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00885 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00887 →  pos=(29, 5)  dist= 55  WALL×1
#   t00888 →  pos=(29, 5)  dist= 55  WALL×1
#   t00889 →  pos=(29, 5)  dist= 55  WALL×1
#   t00891 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00892 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00893 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00895 →  pos=(29, 5)  dist= 55  WALL×1
#   t00896 →  pos=(29, 5)  dist= 55  WALL×1
#   t00897 →  pos=(29, 5)  dist= 55  WALL×1
#   t00900 →  pos=(29, 5)  dist= 55  WALL×1
#   t00901 →  pos=(29, 5)  dist= 55  WALL×1
#   t00902 →  pos=(29, 5)  dist= 55  WALL×1
#   t00904 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00905 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00906 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00908 →  pos=(29, 5)  dist= 55  WALL×1
#   t00909 →  pos=(29, 5)  dist= 55  WALL×1
#   t00910 →  pos=(29, 5)  dist= 55  WALL×1
#   t00913 →  pos=(29, 5)  dist= 55  WALL×1
#   t00914 →  pos=(29, 5)  dist= 55  WALL×1
#   t00915 →  pos=(29, 5)  dist= 55  WALL×1
#   t00918 →  pos=(29, 5)  dist= 55  WALL×1
#   t00919 →  pos=(29, 5)  dist= 55  WALL×1
#   t00920 →  pos=(29, 5)  dist= 55  WALL×1
#   t00923 →  pos=(29, 5)  dist= 55  WALL×1
#   t00924 →  pos=(29, 5)  dist= 55  WALL×1
#   t00925 →  pos=(29, 5)  dist= 55  WALL×1
#   t00927 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00928 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00929 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00931 →  pos=(29, 5)  dist= 55  WALL×1
#   t00932 →  pos=(29, 5)  dist= 55  WALL×1
#   t00933 →  pos=(29, 5)  dist= 55  WALL×1
#   t00936 →  pos=(29, 5)  dist= 55  WALL×1
#   t00937 →  pos=(29, 5)  dist= 55  WALL×1
#   t00938 →  pos=(29, 5)  dist= 55  WALL×1
#   t00940 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00941 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00942 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00944 →  pos=(29, 5)  dist= 55  WALL×1
#   t00945 →  pos=(29, 5)  dist= 55  WALL×1
#   t00946 →  pos=(29, 5)  dist= 55  WALL×1
#   t00948 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00949 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00950 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00952 →  pos=(29, 5)  dist= 55  WALL×1
#   t00953 →  pos=(29, 5)  dist= 55  WALL×1
#   t00954 →  pos=(29, 5)  dist= 55  WALL×1
#   t00957 →  pos=(29, 5)  dist= 55  WALL×1
#   t00958 →  pos=(29, 5)  dist= 55  WALL×1
#   t00959 →  pos=(29, 5)  dist= 55  WALL×1
#   t00961 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00962 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00963 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00965 →  pos=(29, 5)  dist= 55  WALL×1
#   t00966 →  pos=(29, 5)  dist= 55  WALL×1
#   t00967 →  pos=(29, 5)  dist= 55  WALL×1
#   t00969 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00970 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00971 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00973 →  pos=(29, 5)  dist= 55  WALL×1
#   t00974 →  pos=(29, 5)  dist= 55  WALL×1
#   t00975 →  pos=(29, 5)  dist= 55  WALL×1
#   t00977 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00978 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00979 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00981 →  pos=(29, 5)  dist= 55  WALL×1
#   t00982 →  pos=(29, 5)  dist= 55  WALL×1
#   t00983 →  pos=(29, 5)  dist= 55  WALL×1
#   t00985 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00986 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00987 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t00989 →  pos=(29, 5)  dist= 55  WALL×1
#   t00990 →  pos=(29, 5)  dist= 55  WALL×1
#   t00991 →  pos=(29, 5)  dist= 55  WALL×1
#   t00994 →  pos=(29, 5)  dist= 55  WALL×1
#   t00995 →  pos=(29, 5)  dist= 55  WALL×1
#   t00996 →  pos=(29, 5)  dist= 55  WALL×1
#   t00999 →  pos=(29, 5)  dist= 55  WALL×1
#   t01000 →  pos=(29, 5)  dist= 55  WALL×1
#   t01001 →  pos=(29, 5)  dist= 55  WALL×1
#   t01004 →  pos=(29, 5)  dist= 55  WALL×1
#   t01005 →  pos=(29, 5)  dist= 55  WALL×1
#   t01006 →  pos=(29, 5)  dist= 55  WALL×1
#   t01009 →  pos=(29, 5)  dist= 55  WALL×1
#   t01010 →  pos=(29, 5)  dist= 55  WALL×1
#   t01011 →  pos=(29, 5)  dist= 55  WALL×1
#   t01013 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01014 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01015 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01017 →  pos=(29, 5)  dist= 55  WALL×1
#   t01018 →  pos=(29, 5)  dist= 55  WALL×1
#   t01019 →  pos=(29, 5)  dist= 55  WALL×1
#   t01021 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01022 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01023 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01025 →  pos=(29, 5)  dist= 55  WALL×1
#   t01026 →  pos=(29, 5)  dist= 55  WALL×1
#   t01027 →  pos=(29, 5)  dist= 55  WALL×1
#   t01030 →  pos=(29, 5)  dist= 55  WALL×1
#   t01031 →  pos=(29, 5)  dist= 55  WALL×1
#   t01032 →  pos=(29, 5)  dist= 55  WALL×1
#   t01034 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01035 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01036 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01038 →  pos=(29, 5)  dist= 55  WALL×1
#   t01039 →  pos=(29, 5)  dist= 55  WALL×1
#   t01040 →  pos=(29, 5)  dist= 55  WALL×1
#   t01043 →  pos=(29, 5)  dist= 55  WALL×1
#   t01044 →  pos=(29, 5)  dist= 55  WALL×1
#   t01045 →  pos=(29, 5)  dist= 55  WALL×1
#   t01047 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01048 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01049 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01050 ↓  pos=(29, 5)  dist= 55
#   t01051 →  pos=(29, 5)  dist= 55  WALL×1
#   t01052 →  pos=(29, 5)  dist= 55  WALL×1
#   t01053 →  pos=(29, 5)  dist= 55  WALL×1
#   t01055 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01056 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01057 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01059 →  pos=(29, 5)  dist= 55  WALL×1
#   t01060 →  pos=(29, 5)  dist= 55  WALL×1
#   t01061 →  pos=(29, 5)  dist= 55  WALL×1
#   t01063 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01064 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01065 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01067 →  pos=(29, 5)  dist= 55  WALL×1
#   t01068 →  pos=(29, 5)  dist= 55  WALL×1
#   t01069 →  pos=(29, 5)  dist= 55  WALL×1
#   t01071 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01072 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01073 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01075 →  pos=(29, 5)  dist= 55  WALL×1
#   t01076 →  pos=(29, 5)  dist= 55  WALL×1
#   t01077 →  pos=(29, 5)  dist= 55  WALL×1
#   t01080 →  pos=(29, 5)  dist= 55  WALL×1
#   t01081 →  pos=(29, 5)  dist= 55  WALL×1
#   t01082 →  pos=(29, 5)  dist= 55  WALL×1
#   t01084 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01085 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01086 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01088 →  pos=(29, 5)  dist= 55  WALL×1
#   t01089 →  pos=(29, 5)  dist= 55  WALL×1
#   t01090 →  pos=(29, 5)  dist= 55  WALL×1
#   t01092 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01093 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01094 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01096 →  pos=(29, 5)  dist= 55  WALL×1
#   t01097 →  pos=(29, 5)  dist= 55  WALL×1
#   t01098 →  pos=(29, 5)  dist= 55  WALL×1
#   t01100 →  pos=(29, 5)  dist= 55
#   t01101 →  pos=(29, 5)  dist= 55  WALL×1
#   t01102 →  pos=(29, 5)  dist= 55  WALL×1
#   t01103 →  pos=(29, 5)  dist= 55  WALL×1
#   t01105 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01106 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01107 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01109 →  pos=(29, 5)  dist= 55  WALL×1
#   t01110 →  pos=(29, 5)  dist= 55  WALL×1
#   t01111 →  pos=(29, 5)  dist= 55  WALL×1
#   t01114 →  pos=(29, 5)  dist= 55  WALL×1
#   t01115 →  pos=(29, 5)  dist= 55  WALL×1
#   t01116 →  pos=(29, 5)  dist= 55  WALL×1
#   t01119 →  pos=(29, 5)  dist= 55  WALL×1
#   t01120 →  pos=(29, 5)  dist= 55  WALL×1
#   t01121 →  pos=(29, 5)  dist= 55  WALL×1
#   t01124 →  pos=(29, 5)  dist= 55  WALL×1
#   t01125 →  pos=(29, 5)  dist= 55  WALL×1
#   t01126 →  pos=(29, 5)  dist= 55  WALL×1
#   t01129 →  pos=(29, 5)  dist= 55  WALL×1
#   t01130 →  pos=(29, 5)  dist= 55  WALL×1
#   t01131 →  pos=(29, 5)  dist= 55  WALL×1
#   t01133 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01134 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01135 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01137 →  pos=(29, 5)  dist= 55  WALL×1
#   t01138 →  pos=(29, 5)  dist= 55  WALL×1
#   t01139 →  pos=(29, 5)  dist= 55  WALL×1
#   t01142 →  pos=(29, 5)  dist= 55  WALL×1
#   t01143 →  pos=(29, 5)  dist= 55  WALL×1
#   t01144 →  pos=(29, 5)  dist= 55  WALL×1
#   t01146 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01147 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01148 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01150 →  pos=(29, 5)  dist= 55  WALL×1
#   t01151 →  pos=(29, 5)  dist= 55  WALL×1
#   t01152 →  pos=(29, 5)  dist= 55  WALL×1
#   t01155 →  pos=(29, 5)  dist= 55  WALL×1
#   t01156 →  pos=(29, 5)  dist= 55  WALL×1
#   t01157 →  pos=(29, 5)  dist= 55  WALL×1
#   t01160 →  pos=(29, 5)  dist= 55  WALL×1
#   t01161 →  pos=(29, 5)  dist= 55  WALL×1
#   t01162 →  pos=(29, 5)  dist= 55  WALL×1
#   t01164 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01165 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01166 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01168 →  pos=(29, 5)  dist= 55  WALL×1
#   t01169 →  pos=(29, 5)  dist= 55  WALL×1
#   t01170 →  pos=(29, 5)  dist= 55  WALL×1
#   t01173 →  pos=(29, 5)  dist= 55  WALL×1
#   t01174 →  pos=(29, 5)  dist= 55  WALL×1
#   t01175 →  pos=(29, 5)  dist= 55  WALL×1
#   t01177 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01178 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01179 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01181 →  pos=(29, 5)  dist= 55  WALL×1
#   t01182 →  pos=(29, 5)  dist= 55  WALL×1
#   t01183 →  pos=(29, 5)  dist= 55  WALL×1
#   t01186 →  pos=(29, 5)  dist= 55  WALL×1
#   t01187 →  pos=(29, 5)  dist= 55  WALL×1
#   t01188 →  pos=(29, 5)  dist= 55  WALL×1
#   t01191 →  pos=(29, 5)  dist= 55  WALL×1
#   t01192 →  pos=(29, 5)  dist= 55  WALL×1
#   t01193 →  pos=(29, 5)  dist= 55  WALL×1
#   t01196 →  pos=(29, 5)  dist= 55  WALL×1
#   t01197 →  pos=(29, 5)  dist= 55  WALL×1
#   t01198 →  pos=(29, 5)  dist= 55  WALL×1
#   t01200 →  pos=(29, 5)  dist= 55
#   t01201 →  pos=(29, 5)  dist= 55  WALL×1
#   t01202 →  pos=(29, 5)  dist= 55  WALL×1
#   t01203 →  pos=(29, 5)  dist= 55  WALL×1
#   t01206 →  pos=(29, 5)  dist= 55  WALL×1
#   t01207 →  pos=(29, 5)  dist= 55  WALL×1
#   t01208 →  pos=(29, 5)  dist= 55  WALL×1
#   t01211 →  pos=(29, 5)  dist= 55  WALL×1
#   t01212 →  pos=(29, 5)  dist= 55  WALL×1
#   t01213 →  pos=(29, 5)  dist= 55  WALL×1
#   t01216 →  pos=(29, 5)  dist= 55  WALL×1
#   t01217 →  pos=(29, 5)  dist= 55  WALL×1
#   t01218 →  pos=(29, 5)  dist= 55  WALL×1
#   t01220 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01221 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01222 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01224 →  pos=(29, 5)  dist= 55  WALL×1
#   t01225 →  pos=(29, 5)  dist= 55  WALL×1
#   t01226 →  pos=(29, 5)  dist= 55  WALL×1
#   t01229 →  pos=(29, 5)  dist= 55  WALL×1
#   t01230 →  pos=(29, 5)  dist= 55  WALL×1
#   t01231 →  pos=(29, 5)  dist= 55  WALL×1
#   t01233 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01234 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01235 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01237 →  pos=(29, 5)  dist= 55  WALL×1
#   t01238 →  pos=(29, 5)  dist= 55  WALL×1
#   t01239 →  pos=(29, 5)  dist= 55  WALL×1
#   t01242 →  pos=(29, 5)  dist= 55  WALL×1
#   t01243 →  pos=(29, 5)  dist= 55  WALL×1
#   t01244 →  pos=(29, 5)  dist= 55  WALL×1
#   t01247 →  pos=(29, 5)  dist= 55  WALL×1
#   t01248 →  pos=(29, 5)  dist= 55  WALL×1
#   t01249 →  pos=(29, 5)  dist= 55  WALL×1
#   t01250 ↑  pos=(28, 5)  dist= 54
#   t01251 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01252 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01253 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01255 →  pos=(29, 5)  dist= 55  WALL×1
#   t01256 →  pos=(29, 5)  dist= 55  WALL×1
#   t01257 →  pos=(29, 5)  dist= 55  WALL×1
#   t01259 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01260 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01261 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01263 →  pos=(29, 5)  dist= 55  WALL×1
#   t01264 →  pos=(29, 5)  dist= 55  WALL×1
#   t01265 →  pos=(29, 5)  dist= 55  WALL×1
#   t01267 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01268 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01269 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01271 →  pos=(29, 5)  dist= 55  WALL×1
#   t01272 →  pos=(29, 5)  dist= 55  WALL×1
#   t01273 →  pos=(29, 5)  dist= 55  WALL×1
#   t01276 →  pos=(29, 5)  dist= 55  WALL×1
#   t01277 →  pos=(29, 5)  dist= 55  WALL×1
#   t01278 →  pos=(29, 5)  dist= 55  WALL×1
#   t01280 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01281 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01282 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01284 →  pos=(29, 5)  dist= 55  WALL×1
#   t01285 →  pos=(29, 5)  dist= 55  WALL×1
#   t01286 →  pos=(29, 5)  dist= 55  WALL×1
#   t01289 →  pos=(29, 5)  dist= 55  WALL×1
#   t01290 →  pos=(29, 5)  dist= 55  WALL×1
#   t01291 →  pos=(29, 5)  dist= 55  WALL×1
#   t01294 →  pos=(29, 5)  dist= 55  WALL×1
#   t01295 →  pos=(29, 5)  dist= 55  WALL×1
#   t01296 →  pos=(29, 5)  dist= 55  WALL×1
#   t01298 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01299 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01300 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01302 →  pos=(29, 5)  dist= 55  WALL×1
#   t01303 →  pos=(29, 5)  dist= 55  WALL×1
#   t01304 →  pos=(29, 5)  dist= 55  WALL×1
#   t01307 →  pos=(29, 5)  dist= 55  WALL×1
#   t01308 →  pos=(29, 5)  dist= 55  WALL×1
#   t01309 →  pos=(29, 5)  dist= 55  WALL×1
#   t01312 →  pos=(29, 5)  dist= 55  WALL×1
#   t01313 →  pos=(29, 5)  dist= 55  WALL×1
#   t01314 →  pos=(29, 5)  dist= 55  WALL×1
#   t01316 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01317 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01318 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01320 →  pos=(29, 5)  dist= 55  WALL×1
#   t01321 →  pos=(29, 5)  dist= 55  WALL×1
#   t01322 →  pos=(29, 5)  dist= 55  WALL×1
#   t01324 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01325 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01326 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01328 →  pos=(29, 5)  dist= 55  WALL×1
#   t01329 →  pos=(29, 5)  dist= 55  WALL×1
#   t01330 →  pos=(29, 5)  dist= 55  WALL×1
#   t01332 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01333 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01334 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01336 →  pos=(29, 5)  dist= 55  WALL×1
#   t01337 →  pos=(29, 5)  dist= 55  WALL×1
#   t01338 →  pos=(29, 5)  dist= 55  WALL×1
#   t01341 →  pos=(29, 5)  dist= 55  WALL×1
#   t01342 →  pos=(29, 5)  dist= 55  WALL×1
#   t01343 →  pos=(29, 5)  dist= 55  WALL×1
#   t01345 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01346 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01347 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01349 →  pos=(29, 5)  dist= 55  WALL×1
#   t01350 →  pos=(29, 5)  dist= 55  WALL×1
#   t01351 →  pos=(29, 5)  dist= 55  WALL×1
#   t01353 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01354 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01355 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01357 →  pos=(29, 5)  dist= 55  WALL×1
#   t01358 →  pos=(29, 5)  dist= 55  WALL×1
#   t01359 →  pos=(29, 5)  dist= 55  WALL×1
#   t01362 →  pos=(29, 5)  dist= 55  WALL×1
#   t01363 →  pos=(29, 5)  dist= 55  WALL×1
#   t01364 →  pos=(29, 5)  dist= 55  WALL×1
#   t01366 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01367 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01368 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01370 →  pos=(29, 5)  dist= 55  WALL×1
#   t01371 →  pos=(29, 5)  dist= 55  WALL×1
#   t01372 →  pos=(29, 5)  dist= 55  WALL×1
#   t01375 →  pos=(29, 5)  dist= 55  WALL×1
#   t01376 →  pos=(29, 5)  dist= 55  WALL×1
#   t01377 →  pos=(29, 5)  dist= 55  WALL×1
#   t01379 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01380 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01381 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01383 →  pos=(29, 5)  dist= 55  WALL×1
#   t01384 →  pos=(29, 5)  dist= 55  WALL×1
#   t01385 →  pos=(29, 5)  dist= 55  WALL×1
#   t01387 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01388 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01389 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01391 →  pos=(29, 5)  dist= 55  WALL×1
#   t01392 →  pos=(29, 5)  dist= 55  WALL×1
#   t01393 →  pos=(29, 5)  dist= 55  WALL×1
#   t01396 →  pos=(29, 5)  dist= 55  WALL×1
#   t01397 →  pos=(29, 5)  dist= 55  WALL×1
#   t01398 →  pos=(29, 5)  dist= 55  WALL×1
#   t01400 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01401 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01402 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01404 →  pos=(29, 5)  dist= 55  WALL×1
#   t01405 →  pos=(29, 5)  dist= 55  WALL×1
#   t01406 →  pos=(29, 5)  dist= 55  WALL×1
#   t01409 →  pos=(29, 5)  dist= 55  WALL×1
#   t01410 →  pos=(29, 5)  dist= 55  WALL×1
#   t01411 →  pos=(29, 5)  dist= 55  WALL×1
#   t01414 →  pos=(29, 5)  dist= 55  WALL×1
#   t01415 →  pos=(29, 5)  dist= 55  WALL×1
#   t01416 →  pos=(29, 5)  dist= 55  WALL×1
#   t01418 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01419 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01420 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01422 →  pos=(29, 5)  dist= 55  WALL×1
#   t01423 →  pos=(29, 5)  dist= 55  WALL×1
#   t01424 →  pos=(29, 5)  dist= 55  WALL×1
#   t01427 →  pos=(29, 5)  dist= 55  WALL×1
#   t01428 →  pos=(29, 5)  dist= 55  WALL×1
#   t01429 →  pos=(29, 5)  dist= 55  WALL×1
#   t01432 →  pos=(29, 5)  dist= 55  WALL×1
#   t01433 →  pos=(29, 5)  dist= 55  WALL×1
#   t01434 →  pos=(29, 5)  dist= 55  WALL×1
#   t01437 →  pos=(29, 5)  dist= 55  WALL×1
#   t01438 →  pos=(29, 5)  dist= 55  WALL×1
#   t01439 →  pos=(29, 5)  dist= 55  WALL×1
#   t01442 →  pos=(29, 5)  dist= 55  WALL×1
#   t01443 →  pos=(29, 5)  dist= 55  WALL×1
#   t01444 →  pos=(29, 5)  dist= 55  WALL×1
#   t01446 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01447 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01448 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01450 →  pos=(29, 5)  dist= 55  WALL×1
#   t01451 →  pos=(29, 5)  dist= 55  WALL×1
#   t01452 →  pos=(29, 5)  dist= 55  WALL×1
#   t01455 →  pos=(29, 5)  dist= 55  WALL×1
#   t01456 →  pos=(29, 5)  dist= 55  WALL×1
#   t01457 →  pos=(29, 5)  dist= 55  WALL×1
#   t01460 →  pos=(29, 5)  dist= 55  WALL×1
#   t01461 →  pos=(29, 5)  dist= 55  WALL×1
#   t01462 →  pos=(29, 5)  dist= 55  WALL×1
#   t01465 →  pos=(29, 5)  dist= 55  WALL×1
#   t01466 →  pos=(29, 5)  dist= 55  WALL×1
#   t01467 →  pos=(29, 5)  dist= 55  WALL×1
#   t01470 →  pos=(29, 5)  dist= 55  WALL×1
#   t01471 →  pos=(29, 5)  dist= 55  WALL×1
#   t01472 →  pos=(29, 5)  dist= 55  WALL×1
#   t01475 →  pos=(29, 5)  dist= 55  WALL×1
#   t01476 →  pos=(29, 5)  dist= 55  WALL×1
#   t01477 →  pos=(29, 5)  dist= 55  WALL×1
#   t01480 →  pos=(29, 5)  dist= 55  WALL×1
#   t01481 →  pos=(29, 5)  dist= 55  WALL×1
#   t01482 →  pos=(29, 5)  dist= 55  WALL×1
#   t01485 →  pos=(29, 5)  dist= 55  WALL×1
#   t01486 →  pos=(29, 5)  dist= 55  WALL×1
#   t01487 →  pos=(29, 5)  dist= 55  WALL×1
#   t01490 →  pos=(29, 5)  dist= 55  WALL×1
#   t01491 →  pos=(29, 5)  dist= 55  WALL×1
#   t01492 →  pos=(29, 5)  dist= 55  WALL×1
#   t01494 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01495 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01496 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01498 →  pos=(29, 5)  dist= 55  WALL×1
#   t01499 →  pos=(29, 5)  dist= 55  WALL×1
#   t01500 →  pos=(29, 5)  dist= 55  WALL×1
#   t01503 →  pos=(29, 5)  dist= 55  WALL×1
#   t01504 →  pos=(29, 5)  dist= 55  WALL×1
#   t01505 →  pos=(29, 5)  dist= 55  WALL×1
#   t01508 →  pos=(29, 5)  dist= 55  WALL×1
#   t01509 →  pos=(29, 5)  dist= 55  WALL×1
#   t01510 →  pos=(29, 5)  dist= 55  WALL×1
#   t01513 →  pos=(29, 5)  dist= 55  WALL×1
#   t01514 →  pos=(29, 5)  dist= 55  WALL×1
#   t01515 →  pos=(29, 5)  dist= 55  WALL×1
#   t01517 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01518 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01519 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01521 →  pos=(29, 5)  dist= 55  WALL×1
#   t01522 →  pos=(29, 5)  dist= 55  WALL×1
#   t01523 →  pos=(29, 5)  dist= 55  WALL×1
#   t01525 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01526 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01527 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01529 →  pos=(29, 5)  dist= 55  WALL×1
#   t01530 →  pos=(29, 5)  dist= 55  WALL×1
#   t01531 →  pos=(29, 5)  dist= 55  WALL×1
#   t01533 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01534 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01535 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01537 →  pos=(29, 5)  dist= 55  WALL×1
#   t01538 →  pos=(29, 5)  dist= 55  WALL×1
#   t01539 →  pos=(29, 5)  dist= 55  WALL×1
#   t01542 →  pos=(29, 5)  dist= 55  WALL×1
#   t01543 →  pos=(29, 5)  dist= 55  WALL×1
#   t01544 →  pos=(29, 5)  dist= 55  WALL×1
#   t01546 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01547 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01548 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01550 →  pos=(29, 5)  dist= 55  WALL×1
#   t01551 →  pos=(29, 5)  dist= 55  WALL×1
#   t01552 →  pos=(29, 5)  dist= 55  WALL×1
#   t01555 →  pos=(29, 5)  dist= 55  WALL×1
#   t01556 →  pos=(29, 5)  dist= 55  WALL×1
#   t01557 →  pos=(29, 5)  dist= 55  WALL×1
#   t01559 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01560 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01561 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01563 →  pos=(29, 5)  dist= 55  WALL×1
#   t01564 →  pos=(29, 5)  dist= 55  WALL×1
#   t01565 →  pos=(29, 5)  dist= 55  WALL×1
#   t01568 →  pos=(29, 5)  dist= 55  WALL×1
#   t01569 →  pos=(29, 5)  dist= 55  WALL×1
#   t01570 →  pos=(29, 5)  dist= 55  WALL×1
#   t01573 →  pos=(29, 5)  dist= 55  WALL×1
#   t01574 →  pos=(29, 5)  dist= 55  WALL×1
#   t01575 →  pos=(29, 5)  dist= 55  WALL×1
#   t01578 →  pos=(29, 5)  dist= 55  WALL×1
#   t01579 →  pos=(29, 5)  dist= 55  WALL×1
#   t01580 →  pos=(29, 5)  dist= 55  WALL×1
#   t01583 →  pos=(29, 5)  dist= 55  WALL×1
#   t01584 →  pos=(29, 5)  dist= 55  WALL×1
#   t01585 →  pos=(29, 5)  dist= 55  WALL×1
#   t01588 →  pos=(29, 5)  dist= 55  WALL×1
#   t01589 →  pos=(29, 5)  dist= 55  WALL×1
#   t01590 →  pos=(29, 5)  dist= 55  WALL×1
#   t01592 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01593 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01594 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01596 →  pos=(29, 5)  dist= 55  WALL×1
#   t01597 →  pos=(29, 5)  dist= 55  WALL×1
#   t01598 →  pos=(29, 5)  dist= 55  WALL×1
#   t01600 →  pos=(29, 5)  dist= 55
#   t01601 →  pos=(29, 5)  dist= 55  WALL×1
#   t01602 →  pos=(29, 5)  dist= 55  WALL×1
#   t01603 →  pos=(29, 5)  dist= 55  WALL×1
#   t01605 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01606 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01607 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01609 →  pos=(29, 5)  dist= 55  WALL×1
#   t01610 →  pos=(29, 5)  dist= 55  WALL×1
#   t01611 →  pos=(29, 5)  dist= 55  WALL×1
#   t01613 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01614 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01615 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01617 →  pos=(29, 5)  dist= 55  WALL×1
#   t01618 →  pos=(29, 5)  dist= 55  WALL×1
#   t01619 →  pos=(29, 5)  dist= 55  WALL×1
#   t01621 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01622 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01623 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01625 →  pos=(29, 5)  dist= 55  WALL×1
#   t01626 →  pos=(29, 5)  dist= 55  WALL×1
#   t01627 →  pos=(29, 5)  dist= 55  WALL×1
#   t01629 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01630 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01631 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01633 →  pos=(29, 5)  dist= 55  WALL×1
#   t01634 →  pos=(29, 5)  dist= 55  WALL×1
#   t01635 →  pos=(29, 5)  dist= 55  WALL×1
#   t01638 →  pos=(29, 5)  dist= 55  WALL×1
#   t01639 →  pos=(29, 5)  dist= 55  WALL×1
#   t01640 →  pos=(29, 5)  dist= 55  WALL×1
#   t01643 →  pos=(29, 5)  dist= 55  WALL×1
#   t01644 →  pos=(29, 5)  dist= 55  WALL×1
#   t01645 →  pos=(29, 5)  dist= 55  WALL×1
#   t01647 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01648 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01649 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01650 ↓  pos=(29, 5)  dist= 55
#   t01651 →  pos=(29, 5)  dist= 55  WALL×1
#   t01652 →  pos=(29, 5)  dist= 55  WALL×1
#   t01653 →  pos=(29, 5)  dist= 55  WALL×1
#   t01656 →  pos=(29, 5)  dist= 55  WALL×1
#   t01657 →  pos=(29, 5)  dist= 55  WALL×1
#   t01658 →  pos=(29, 5)  dist= 55  WALL×1
#   t01660 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01661 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01662 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01664 →  pos=(29, 5)  dist= 55  WALL×1
#   t01665 →  pos=(29, 5)  dist= 55  WALL×1
#   t01666 →  pos=(29, 5)  dist= 55  WALL×1
#   t01668 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01669 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01670 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01672 →  pos=(29, 5)  dist= 55  WALL×1
#   t01673 →  pos=(29, 5)  dist= 55  WALL×1
#   t01674 →  pos=(29, 5)  dist= 55  WALL×1
#   t01677 →  pos=(29, 5)  dist= 55  WALL×1
#   t01678 →  pos=(29, 5)  dist= 55  WALL×1
#   t01679 →  pos=(29, 5)  dist= 55  WALL×1
#   t01682 →  pos=(29, 5)  dist= 55  WALL×1
#   t01683 →  pos=(29, 5)  dist= 55  WALL×1
#   t01684 →  pos=(29, 5)  dist= 55  WALL×1
#   t01686 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01687 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01688 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01690 →  pos=(29, 5)  dist= 55  WALL×1
#   t01691 →  pos=(29, 5)  dist= 55  WALL×1
#   t01692 →  pos=(29, 5)  dist= 55  WALL×1
#   t01695 →  pos=(29, 5)  dist= 55  WALL×1
#   t01696 →  pos=(29, 5)  dist= 55  WALL×1
#   t01697 →  pos=(29, 5)  dist= 55  WALL×1
#   t01700 →  pos=(29, 5)  dist= 55  WALL×1
#   t01701 →  pos=(29, 5)  dist= 55  WALL×1
#   t01702 →  pos=(29, 5)  dist= 55  WALL×1
#   t01704 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01705 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01706 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01708 →  pos=(29, 5)  dist= 55  WALL×1
#   t01709 →  pos=(29, 5)  dist= 55  WALL×1
#   t01710 →  pos=(29, 5)  dist= 55  WALL×1
#   t01713 →  pos=(29, 5)  dist= 55  WALL×1
#   t01714 →  pos=(29, 5)  dist= 55  WALL×1
#   t01715 →  pos=(29, 5)  dist= 55  WALL×1
#   t01718 →  pos=(29, 5)  dist= 55  WALL×1
#   t01719 →  pos=(29, 5)  dist= 55  WALL×1
#   t01720 →  pos=(29, 5)  dist= 55  WALL×1
#   t01722 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01723 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01724 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01726 →  pos=(29, 5)  dist= 55  WALL×1
#   t01727 →  pos=(29, 5)  dist= 55  WALL×1
#   t01728 →  pos=(29, 5)  dist= 55  WALL×1
#   t01730 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01731 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01732 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01734 →  pos=(29, 5)  dist= 55  WALL×1
#   t01735 →  pos=(29, 5)  dist= 55  WALL×1
#   t01736 →  pos=(29, 5)  dist= 55  WALL×1
#   t01738 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01739 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01740 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01742 →  pos=(29, 5)  dist= 55  WALL×1
#   t01743 →  pos=(29, 5)  dist= 55  WALL×1
#   t01744 →  pos=(29, 5)  dist= 55  WALL×1
#   t01746 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01747 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01748 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01750 →  pos=(29, 5)  dist= 55  WALL×1
#   t01751 →  pos=(29, 5)  dist= 55  WALL×1
#   t01752 →  pos=(29, 5)  dist= 55  WALL×1
#   t01754 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01755 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01756 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01758 →  pos=(29, 5)  dist= 55  WALL×1
#   t01759 →  pos=(29, 5)  dist= 55  WALL×1
#   t01760 →  pos=(29, 5)  dist= 55  WALL×1
#   t01762 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01763 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01764 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01766 →  pos=(29, 5)  dist= 55  WALL×1
#   t01767 →  pos=(29, 5)  dist= 55  WALL×1
#   t01768 →  pos=(29, 5)  dist= 55  WALL×1
#   t01771 →  pos=(29, 5)  dist= 55  WALL×1
#   t01772 →  pos=(29, 5)  dist= 55  WALL×1
#   t01773 →  pos=(29, 5)  dist= 55  WALL×1
#   t01776 →  pos=(29, 5)  dist= 55  WALL×1
#   t01777 →  pos=(29, 5)  dist= 55  WALL×1
#   t01778 →  pos=(29, 5)  dist= 55  WALL×1
#   t01780 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01781 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01782 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01784 →  pos=(29, 5)  dist= 55  WALL×1
#   t01785 →  pos=(29, 5)  dist= 55  WALL×1
#   t01786 →  pos=(29, 5)  dist= 55  WALL×1
#   t01789 →  pos=(29, 5)  dist= 55  WALL×1
#   t01790 →  pos=(29, 5)  dist= 55  WALL×1
#   t01791 →  pos=(29, 5)  dist= 55  WALL×1
#   t01793 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01794 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01795 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01797 →  pos=(29, 5)  dist= 55  WALL×1
#   t01798 →  pos=(29, 5)  dist= 55  WALL×1
#   t01799 →  pos=(29, 5)  dist= 55  WALL×1
#   t01800 ↑  pos=(28, 5)  dist= 54
#   t01801 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01802 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01803 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01805 →  pos=(29, 5)  dist= 55  WALL×1
#   t01806 →  pos=(29, 5)  dist= 55  WALL×1
#   t01807 →  pos=(29, 5)  dist= 55  WALL×1
#   t01810 →  pos=(29, 5)  dist= 55  WALL×1
#   t01811 →  pos=(29, 5)  dist= 55  WALL×1
#   t01812 →  pos=(29, 5)  dist= 55  WALL×1
#   t01814 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01815 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01816 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01818 →  pos=(29, 5)  dist= 55  WALL×1
#   t01819 →  pos=(29, 5)  dist= 55  WALL×1
#   t01820 →  pos=(29, 5)  dist= 55  WALL×1
#   t01822 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01823 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01824 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01826 →  pos=(29, 5)  dist= 55  WALL×1
#   t01827 →  pos=(29, 5)  dist= 55  WALL×1
#   t01828 →  pos=(29, 5)  dist= 55  WALL×1
#   t01830 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01831 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01832 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t01834 →  pos=(29, 5)  dist= 55  WALL×1
#   t01835 →  pos=(29, 5)  dist= 55  WALL×1
#   t01836 →  pos=(29, 5)  dist= 55  WALL×1
#   t01838 ↑  pos=(28, 5)  dist= 54  WALL×1
# ...
#   t09468 →  pos=(29, 5)  dist= 55  WALL×1
#   t09471 →  pos=(29, 5)  dist= 55  WALL×1
#   t09472 →  pos=(29, 5)  dist= 55  WALL×1
#   t09473 →  pos=(29, 5)  dist= 55  WALL×1
#   t09475 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09476 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09477 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09479 →  pos=(29, 5)  dist= 55  WALL×1
#   t09480 →  pos=(29, 5)  dist= 55  WALL×1
#   t09481 →  pos=(29, 5)  dist= 55  WALL×1
#   t09484 →  pos=(29, 5)  dist= 55  WALL×1
#   t09485 →  pos=(29, 5)  dist= 55  WALL×1
#   t09486 →  pos=(29, 5)  dist= 55  WALL×1
#   t09489 →  pos=(29, 5)  dist= 55  WALL×1
#   t09490 →  pos=(29, 5)  dist= 55  WALL×1
#   t09491 →  pos=(29, 5)  dist= 55  WALL×1
#   t09493 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09494 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09495 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09497 →  pos=(29, 5)  dist= 55  WALL×1
#   t09498 →  pos=(29, 5)  dist= 55  WALL×1
#   t09499 →  pos=(29, 5)  dist= 55  WALL×1
#   t09500 ↑  pos=(28, 5)  dist= 54
#   t09501 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09502 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09503 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09505 →  pos=(29, 5)  dist= 55  WALL×1
#   t09506 →  pos=(29, 5)  dist= 55  WALL×1
#   t09507 →  pos=(29, 5)  dist= 55  WALL×1
#   t09509 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09510 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09511 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09513 →  pos=(29, 5)  dist= 55  WALL×1
#   t09514 →  pos=(29, 5)  dist= 55  WALL×1
#   t09515 →  pos=(29, 5)  dist= 55  WALL×1
#   t09518 →  pos=(29, 5)  dist= 55  WALL×1
#   t09519 →  pos=(29, 5)  dist= 55  WALL×1
#   t09520 →  pos=(29, 5)  dist= 55  WALL×1
#   t09522 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09523 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09524 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09526 →  pos=(29, 5)  dist= 55  WALL×1
#   t09527 →  pos=(29, 5)  dist= 55  WALL×1
#   t09528 →  pos=(29, 5)  dist= 55  WALL×1
#   t09530 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09531 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09532 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09534 →  pos=(29, 5)  dist= 55  WALL×1
#   t09535 →  pos=(29, 5)  dist= 55  WALL×1
#   t09536 →  pos=(29, 5)  dist= 55  WALL×1
#   t09538 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09539 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09540 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09542 →  pos=(29, 5)  dist= 55  WALL×1
#   t09543 →  pos=(29, 5)  dist= 55  WALL×1
#   t09544 →  pos=(29, 5)  dist= 55  WALL×1
#   t09547 →  pos=(29, 5)  dist= 55  WALL×1
#   t09548 →  pos=(29, 5)  dist= 55  WALL×1
#   t09549 →  pos=(29, 5)  dist= 55  WALL×1
#   t09550 ←  pos=(29, 4)  dist= 56
#   t09552 →  pos=(29, 5)  dist= 55  WALL×1
#   t09553 →  pos=(29, 5)  dist= 55  WALL×1
#   t09554 →  pos=(29, 5)  dist= 55  WALL×1
#   t09556 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09557 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09558 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09560 →  pos=(29, 5)  dist= 55  WALL×1
#   t09561 →  pos=(29, 5)  dist= 55  WALL×1
#   t09562 →  pos=(29, 5)  dist= 55  WALL×1
#   t09565 →  pos=(29, 5)  dist= 55  WALL×1
#   t09566 →  pos=(29, 5)  dist= 55  WALL×1
#   t09567 →  pos=(29, 5)  dist= 55  WALL×1
#   t09570 →  pos=(29, 5)  dist= 55  WALL×1
#   t09571 →  pos=(29, 5)  dist= 55  WALL×1
#   t09572 →  pos=(29, 5)  dist= 55  WALL×1
#   t09574 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09575 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09576 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09578 →  pos=(29, 5)  dist= 55  WALL×1
#   t09579 →  pos=(29, 5)  dist= 55  WALL×1
#   t09580 →  pos=(29, 5)  dist= 55  WALL×1
#   t09583 →  pos=(29, 5)  dist= 55  WALL×1
#   t09584 →  pos=(29, 5)  dist= 55  WALL×1
#   t09585 →  pos=(29, 5)  dist= 55  WALL×1
#   t09588 →  pos=(29, 5)  dist= 55  WALL×1
#   t09589 →  pos=(29, 5)  dist= 55  WALL×1
#   t09590 →  pos=(29, 5)  dist= 55  WALL×1
#   t09592 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09593 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09594 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09596 →  pos=(29, 5)  dist= 55  WALL×1
#   t09597 →  pos=(29, 5)  dist= 55  WALL×1
#   t09598 →  pos=(29, 5)  dist= 55  WALL×1
#   t09600 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09601 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09602 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09604 →  pos=(29, 5)  dist= 55  WALL×1
#   t09605 →  pos=(29, 5)  dist= 55  WALL×1
#   t09606 →  pos=(29, 5)  dist= 55  WALL×1
#   t09608 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09609 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09610 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09612 →  pos=(29, 5)  dist= 55  WALL×1
#   t09613 →  pos=(29, 5)  dist= 55  WALL×1
#   t09614 →  pos=(29, 5)  dist= 55  WALL×1
#   t09616 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09617 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09618 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09620 →  pos=(29, 5)  dist= 55  WALL×1
#   t09621 →  pos=(29, 5)  dist= 55  WALL×1
#   t09622 →  pos=(29, 5)  dist= 55  WALL×1
#   t09624 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09625 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09626 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09628 →  pos=(29, 5)  dist= 55  WALL×1
#   t09629 →  pos=(29, 5)  dist= 55  WALL×1
#   t09630 →  pos=(29, 5)  dist= 55  WALL×1
#   t09632 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09633 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09634 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09636 →  pos=(29, 5)  dist= 55  WALL×1
#   t09637 →  pos=(29, 5)  dist= 55  WALL×1
#   t09638 →  pos=(29, 5)  dist= 55  WALL×1
#   t09641 →  pos=(29, 5)  dist= 55  WALL×1
#   t09642 →  pos=(29, 5)  dist= 55  WALL×1
#   t09643 →  pos=(29, 5)  dist= 55  WALL×1
#   t09646 →  pos=(29, 5)  dist= 55  WALL×1
#   t09647 →  pos=(29, 5)  dist= 55  WALL×1
#   t09648 →  pos=(29, 5)  dist= 55  WALL×1
#   t09650 →  pos=(29, 5)  dist= 55
#   t09651 →  pos=(29, 5)  dist= 55  WALL×1
#   t09652 →  pos=(29, 5)  dist= 55  WALL×1
#   t09653 →  pos=(29, 5)  dist= 55  WALL×1
#   t09656 →  pos=(29, 5)  dist= 55  WALL×1
#   t09657 →  pos=(29, 5)  dist= 55  WALL×1
#   t09658 →  pos=(29, 5)  dist= 55  WALL×1
#   t09660 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09661 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09662 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09664 →  pos=(29, 5)  dist= 55  WALL×1
#   t09665 →  pos=(29, 5)  dist= 55  WALL×1
#   t09666 →  pos=(29, 5)  dist= 55  WALL×1
#   t09668 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09669 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09670 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09672 →  pos=(29, 5)  dist= 55  WALL×1
#   t09673 →  pos=(29, 5)  dist= 55  WALL×1
#   t09674 →  pos=(29, 5)  dist= 55  WALL×1
#   t09677 →  pos=(29, 5)  dist= 55  WALL×1
#   t09678 →  pos=(29, 5)  dist= 55  WALL×1
#   t09679 →  pos=(29, 5)  dist= 55  WALL×1
#   t09681 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09682 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09683 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09685 →  pos=(29, 5)  dist= 55  WALL×1
#   t09686 →  pos=(29, 5)  dist= 55  WALL×1
#   t09687 →  pos=(29, 5)  dist= 55  WALL×1
#   t09689 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09690 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09691 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09693 →  pos=(29, 5)  dist= 55  WALL×1
#   t09694 →  pos=(29, 5)  dist= 55  WALL×1
#   t09695 →  pos=(29, 5)  dist= 55  WALL×1
#   t09697 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09698 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09699 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09700 ↓  pos=(29, 5)  dist= 55
#   t09701 →  pos=(29, 5)  dist= 55  WALL×1
#   t09702 →  pos=(29, 5)  dist= 55  WALL×1
#   t09703 →  pos=(29, 5)  dist= 55  WALL×1
#   t09706 →  pos=(29, 5)  dist= 55  WALL×1
#   t09707 →  pos=(29, 5)  dist= 55  WALL×1
#   t09708 →  pos=(29, 5)  dist= 55  WALL×1
#   t09711 →  pos=(29, 5)  dist= 55  WALL×1
#   t09712 →  pos=(29, 5)  dist= 55  WALL×1
#   t09713 →  pos=(29, 5)  dist= 55  WALL×1
#   t09716 →  pos=(29, 5)  dist= 55  WALL×1
#   t09717 →  pos=(29, 5)  dist= 55  WALL×1
#   t09718 →  pos=(29, 5)  dist= 55  WALL×1
#   t09720 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09721 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09722 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09724 →  pos=(29, 5)  dist= 55  WALL×1
#   t09725 →  pos=(29, 5)  dist= 55  WALL×1
#   t09726 →  pos=(29, 5)  dist= 55  WALL×1
#   t09729 →  pos=(29, 5)  dist= 55  WALL×1
#   t09730 →  pos=(29, 5)  dist= 55  WALL×1
#   t09731 →  pos=(29, 5)  dist= 55  WALL×1
#   t09733 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09734 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09735 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09737 →  pos=(29, 5)  dist= 55  WALL×1
#   t09738 →  pos=(29, 5)  dist= 55  WALL×1
#   t09739 →  pos=(29, 5)  dist= 55  WALL×1
#   t09741 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09742 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09743 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09745 →  pos=(29, 5)  dist= 55  WALL×1
#   t09746 →  pos=(29, 5)  dist= 55  WALL×1
#   t09747 →  pos=(29, 5)  dist= 55  WALL×1
#   t09750 →  pos=(29, 5)  dist= 55  WALL×1
#   t09751 →  pos=(29, 5)  dist= 55  WALL×1
#   t09752 →  pos=(29, 5)  dist= 55  WALL×1
#   t09754 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09755 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09756 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09758 →  pos=(29, 5)  dist= 55  WALL×1
#   t09759 →  pos=(29, 5)  dist= 55  WALL×1
#   t09760 →  pos=(29, 5)  dist= 55  WALL×1
#   t09763 →  pos=(29, 5)  dist= 55  WALL×1
#   t09764 →  pos=(29, 5)  dist= 55  WALL×1
#   t09765 →  pos=(29, 5)  dist= 55  WALL×1
#   t09768 →  pos=(29, 5)  dist= 55  WALL×1
#   t09769 →  pos=(29, 5)  dist= 55  WALL×1
#   t09770 →  pos=(29, 5)  dist= 55  WALL×1
#   t09772 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09773 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09774 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09776 →  pos=(29, 5)  dist= 55  WALL×1
#   t09777 →  pos=(29, 5)  dist= 55  WALL×1
#   t09778 →  pos=(29, 5)  dist= 55  WALL×1
#   t09781 →  pos=(29, 5)  dist= 55  WALL×1
#   t09782 →  pos=(29, 5)  dist= 55  WALL×1
#   t09783 →  pos=(29, 5)  dist= 55  WALL×1
#   t09785 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09786 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09787 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09789 →  pos=(29, 5)  dist= 55  WALL×1
#   t09790 →  pos=(29, 5)  dist= 55  WALL×1
#   t09791 →  pos=(29, 5)  dist= 55  WALL×1
#   t09793 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09794 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09795 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09797 →  pos=(29, 5)  dist= 55  WALL×1
#   t09798 →  pos=(29, 5)  dist= 55  WALL×1
#   t09799 →  pos=(29, 5)  dist= 55  WALL×1
#   t09800 ↑  pos=(28, 5)  dist= 54
#   t09801 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09802 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09803 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09805 →  pos=(29, 5)  dist= 55  WALL×1
#   t09806 →  pos=(29, 5)  dist= 55  WALL×1
#   t09807 →  pos=(29, 5)  dist= 55  WALL×1
#   t09809 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09810 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09811 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09813 →  pos=(29, 5)  dist= 55  WALL×1
#   t09814 →  pos=(29, 5)  dist= 55  WALL×1
#   t09815 →  pos=(29, 5)  dist= 55  WALL×1
#   t09818 →  pos=(29, 5)  dist= 55  WALL×1
#   t09819 →  pos=(29, 5)  dist= 55  WALL×1
#   t09820 →  pos=(29, 5)  dist= 55  WALL×1
#   t09823 →  pos=(29, 5)  dist= 55  WALL×1
#   t09824 →  pos=(29, 5)  dist= 55  WALL×1
#   t09825 →  pos=(29, 5)  dist= 55  WALL×1
#   t09827 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09828 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09829 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09831 →  pos=(29, 5)  dist= 55  WALL×1
#   t09832 →  pos=(29, 5)  dist= 55  WALL×1
#   t09833 →  pos=(29, 5)  dist= 55  WALL×1
#   t09836 →  pos=(29, 5)  dist= 55  WALL×1
#   t09837 →  pos=(29, 5)  dist= 55  WALL×1
#   t09838 →  pos=(29, 5)  dist= 55  WALL×1
#   t09841 →  pos=(29, 5)  dist= 55  WALL×1
#   t09842 →  pos=(29, 5)  dist= 55  WALL×1
#   t09843 →  pos=(29, 5)  dist= 55  WALL×1
#   t09846 →  pos=(29, 5)  dist= 55  WALL×1
#   t09847 →  pos=(29, 5)  dist= 55  WALL×1
#   t09848 →  pos=(29, 5)  dist= 55  WALL×1
#   t09850 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09851 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09852 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09854 →  pos=(29, 5)  dist= 55  WALL×1
#   t09855 →  pos=(29, 5)  dist= 55  WALL×1
#   t09856 →  pos=(29, 5)  dist= 55  WALL×1
#   t09859 →  pos=(29, 5)  dist= 55  WALL×1
#   t09860 →  pos=(29, 5)  dist= 55  WALL×1
#   t09861 →  pos=(29, 5)  dist= 55  WALL×1
#   t09864 →  pos=(29, 5)  dist= 55  WALL×1
#   t09865 →  pos=(29, 5)  dist= 55  WALL×1
#   t09866 →  pos=(29, 5)  dist= 55  WALL×1
#   t09868 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09869 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09870 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09872 →  pos=(29, 5)  dist= 55  WALL×1
#   t09873 →  pos=(29, 5)  dist= 55  WALL×1
#   t09874 →  pos=(29, 5)  dist= 55  WALL×1
#   t09877 →  pos=(29, 5)  dist= 55  WALL×1
#   t09878 →  pos=(29, 5)  dist= 55  WALL×1
#   t09879 →  pos=(29, 5)  dist= 55  WALL×1
#   t09881 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09882 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09883 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09885 →  pos=(29, 5)  dist= 55  WALL×1
#   t09886 →  pos=(29, 5)  dist= 55  WALL×1
#   t09887 →  pos=(29, 5)  dist= 55  WALL×1
#   t09890 →  pos=(29, 5)  dist= 55  WALL×1
#   t09891 →  pos=(29, 5)  dist= 55  WALL×1
#   t09892 →  pos=(29, 5)  dist= 55  WALL×1
#   t09894 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09895 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09896 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09898 →  pos=(29, 5)  dist= 55  WALL×1
#   t09899 →  pos=(29, 5)  dist= 55  WALL×1
#   t09900 →  pos=(29, 5)  dist= 55  WALL×1
#   t09903 →  pos=(29, 5)  dist= 55  WALL×1
#   t09904 →  pos=(29, 5)  dist= 55  WALL×1
#   t09905 →  pos=(29, 5)  dist= 55  WALL×1
#   t09907 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09908 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09909 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09911 →  pos=(29, 5)  dist= 55  WALL×1
#   t09912 →  pos=(29, 5)  dist= 55  WALL×1
#   t09913 →  pos=(29, 5)  dist= 55  WALL×1
#   t09915 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09916 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09917 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09919 →  pos=(29, 5)  dist= 55  WALL×1
#   t09920 →  pos=(29, 5)  dist= 55  WALL×1
#   t09921 →  pos=(29, 5)  dist= 55  WALL×1
#   t09924 →  pos=(29, 5)  dist= 55  WALL×1
#   t09925 →  pos=(29, 5)  dist= 55  WALL×1
#   t09926 →  pos=(29, 5)  dist= 55  WALL×1
#   t09928 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09929 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09930 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09932 →  pos=(29, 5)  dist= 55  WALL×1
#   t09933 →  pos=(29, 5)  dist= 55  WALL×1
#   t09934 →  pos=(29, 5)  dist= 55  WALL×1
#   t09936 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09937 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09938 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09940 →  pos=(29, 5)  dist= 55  WALL×1
#   t09941 →  pos=(29, 5)  dist= 55  WALL×1
#   t09942 →  pos=(29, 5)  dist= 55  WALL×1
#   t09944 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09945 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09946 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09948 →  pos=(29, 5)  dist= 55  WALL×1
#   t09949 →  pos=(29, 5)  dist= 55  WALL×1
#   t09950 →  pos=(29, 5)  dist= 55  WALL×1
#   t09952 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09953 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09954 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09956 →  pos=(29, 5)  dist= 55  WALL×1
#   t09957 →  pos=(29, 5)  dist= 55  WALL×1
#   t09958 →  pos=(29, 5)  dist= 55  WALL×1
#   t09961 →  pos=(29, 5)  dist= 55  WALL×1
#   t09962 →  pos=(29, 5)  dist= 55  WALL×1
#   t09963 →  pos=(29, 5)  dist= 55  WALL×1
#   t09966 →  pos=(29, 5)  dist= 55  WALL×1
#   t09967 →  pos=(29, 5)  dist= 55  WALL×1
#   t09968 →  pos=(29, 5)  dist= 55  WALL×1
#   t09970 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09971 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09972 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09974 →  pos=(29, 5)  dist= 55  WALL×1
#   t09975 →  pos=(29, 5)  dist= 55  WALL×1
#   t09976 →  pos=(29, 5)  dist= 55  WALL×1
#   t09979 →  pos=(29, 5)  dist= 55  WALL×1
#   t09980 →  pos=(29, 5)  dist= 55  WALL×1
#   t09981 →  pos=(29, 5)  dist= 55  WALL×1
#   t09984 →  pos=(29, 5)  dist= 55  WALL×1
#   t09985 →  pos=(29, 5)  dist= 55  WALL×1
#   t09986 →  pos=(29, 5)  dist= 55  WALL×1
#   t09989 →  pos=(29, 5)  dist= 55  WALL×1
#   t09990 →  pos=(29, 5)  dist= 55  WALL×1
#   t09991 →  pos=(29, 5)  dist= 55  WALL×1
#   t09994 →  pos=(29, 5)  dist= 55  WALL×1
#   t09995 →  pos=(29, 5)  dist= 55  WALL×1
#   t09996 →  pos=(29, 5)  dist= 55  WALL×1
#   t09998 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t09999 ↑  pos=(28, 5)  dist= 54  WALL×1
#   t10000 ↑  pos=(28, 5)  dist= 54  WALL×1
#   TIMEOUT ✗  turns=10000  deaths=3  explored=108  fitness=+21430
#   env_stats: {'turns_taken': 10000, 'deaths': 3, 'confused': 0, 'cells_explored': 108, 'goal_reached': False}
#
# Fitness: +21430
# Goal reached: False
# Turns: 10000  Deaths: 3  Explored: 108 cells
